# %%
import algorithmTest as at
import createPlotter as cp
import dataTreat as dt
from imp import reload
fileName = 'ecoli-0-1_vs_2-3-5-5-fold'
file = 'ecoli-0-1_vs_2-3-5-5-fold'

# %%
dataMat, labels, features, length = dt.createIR(fileName)

# %%
print(length)
cp.createIRPlotter(dataMat, labels, features, file)
# Out:
# 1220

# %%
precisions = []
recalls = []
f_measures = []

# %%
kValues = []
kNNPrecisions = []
kNNRecalls = [] 
kNNF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNs = at.testKNNByDir(fileName, 'KNN', i)
    kNNPrecisions.append(kNNs[0])
    kNNRecalls.append(kNNs[1])
    kNNF_measures.append(kNNs[2])
# Out:
# 正确率：0.9483333333333335
# 召回率：0.7742105263157895
# 准确率：0.9733908948194664
# f-measure：0.8524713550949737
# 正确率：0.9857142857142858
# 召回率：0.7642105263157895
# 准确率：0.975447409733124
# f-measure：0.8609435421500387
# 正确率：0.7703296703296704
# 召回率：0.5831578947368421
# 准确率：0.956043956043956
# f-measure：0.6638019297660863
# 正确率：0.7846153846153847
# 召回率：0.5936842105263158
# 准确率：0.9580952380952381
# f-measure：0.6759252731758901
# 正确率：0.8
# 召回率：0.5305263157894737
# 准确率：0.952967032967033
# f-measure：0.6379746835443039
# 正确率：0.8
# 召回率：0.551578947368421
# 准确率：0.955018315018315
# f-measure：0.6529595015576324
# 正确率：0.5846153846153846
# 召回率：0.44631578947368417
# 准确率：0.9437362637362637
# f-measure：0.5061891297518065
# 正确率：0.6
# 召回率：0.456842105263158
# 准确率：0.9457875457875458
# f-measure：0.5187250996015936

# %%
kValues = []
kNNIPDCPrecisions = []
kNNIPDCRecalls = [] 
kNNIPDCF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIPDCs = at.testKNNByDir(fileName, 'IPDC_KNN', i)
    kNNIPDCPrecisions.append(kNNIPDCs[0])
    kNNIPDCRecalls.append(kNNIPDCs[1])
    kNNIPDCF_measures.append(kNNIPDCs[2])
# Out:
# 正确率：0.8960000000000001
# 召回率：0.9278947368421052
# 准确率：0.9805703819989535
# f-measure：0.9116684942575173
# 正确率：0.9229665071770334
# 召回率：0.9278947368421052
# 准确率：0.9846572475143904
# f-measure：0.9254240608889801
# 正确率：0.9424836601307189
# 召回率：0.8978947368421053
# 准确率：0.9846624803767661
# f-measure：0.9196490454169922
# 正确率：0.9402777777777779
# 召回率：0.8878947368421052
# 准确率：0.9836420722135009
# f-measure：0.91333578574456
# 正确率：0.9732142857142858
# 召回率：0.8773684210526316
# 准确率：0.9856828885400315
# f-measure：0.9228093163096363
# 正确率：0.9484022556390977
# 召回率：0.8673684210526315
# 准确率：0.9826164311878598
# f-measure：0.9060771578217274
# 正确率：0.9428070175438595
# 召回率：0.8368421052631578
# 准确率：0.9795499738356881
# f-measure：0.886669848912502
# 正确率：0.9428070175438595
# 召回率：0.8368421052631578
# 准确率：0.9795499738356881
# f-measure：0.886669848912502

# %%
kValues = []
kNNIPDSPrecisions = []
kNNIPDSRecalls = [] 
kNNIPDSF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIPDSs = at.testKNNByDir(fileName, 'IPDS_KNN', i)
    kNNIPDSPrecisions.append(kNNIPDSs[0])
    kNNIPDSRecalls.append(kNNIPDSs[1])
    kNNIPDSF_measures.append(kNNIPDSs[2])
# Out:
# 正确率：0.9305555555555556
# 召回率：0.8768421052631578
# 准确率：0.9815907901622187
# f-measure：0.902900684322068
# 正确率：0.96
# 召回率：0.866842105263158
# 准确率：0.983636839351125
# f-measure：0.9110458081244599
# 正确率：0.96
# 召回率：0.866842105263158
# 准确率：0.983636839351125
# f-measure：0.9110458081244599
# 正确率：0.9493506493506494
# 召回率：0.8163157894736841
# 准确率：0.9785295656724229
# f-measure：0.8778214364521111
# 正确率：0.9412698412698413
# 召回率：0.7963157894736842
# 准确率：0.9764887493458921
# f-measure：0.862746587559919
# 正确率：0.9346153846153846
# 召回率：0.7757894736842105
# 准确率：0.9744427001569859
# f-measure：0.8478282481596326
# 正确率：0.919047619047619
# 召回率：0.7663157894736842
# 准确率：0.9734275248560962
# f-measure：0.8357612348689883
# 正确率：0.9
# 召回率：0.7357894736842105
# 准确率：0.9713867085295658
# f-measure：0.8096525096525097

# %%
kValues = []
kNNIPDCSPrecisions = []
kNNIPDCSRecalls = [] 
kNNIPDCSF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIPDCSs = at.testKNNByDir(fileName, 'IPDCS_KNN', i)
    kNNIPDCSPrecisions.append(kNNIPDCSs[0])
    kNNIPDCSRecalls.append(kNNIPDCSs[1])
    kNNIPDCSF_measures.append(kNNIPDCSs[2])
# Out:
# 正确率：0.9098039215686274
# 召回率：0.8873684210526316
# 准确率：0.9795552066980638
# f-measure：0.8984461314069804
# 正确率：0.9193277310924369
# 召回率：0.8973684210526315
# 准确率：0.9815960230245946
# f-measure：0.9082153595208822
# 正确率：0.9356037151702786
# 召回率：0.8978947368421053
# 准确率：0.9836473050758766
# f-measure：0.9163614517364636
# 正确率：0.9319444444444445
# 召回率：0.8773684210526316
# 准确率：0.9816012558869701
# f-measure：0.9038333185193564
# 正确率：0.9466666666666667
# 召回率：0.8568421052631578
# 准确率：0.9815960230245946
# f-measure：0.8995175097276265
# 正确率：0.9533333333333334
# 召回率：0.8368421052631578
# 准确率：0.9805756148613292
# f-measure：0.8912975303802431
# 正确率：0.9558974358974359
# 召回率：0.8468421052631578
# 准确率：0.9815960230245946
# f-measure：0.8980711617496238
# 正确率：0.9533333333333334
# 召回率：0.8368421052631578
# 准确率：0.9805756148613292
# f-measure：0.8912975303802431

# %%
kValues = []
kNNIPNCPrecisions = []
kNNIPNCRecalls = [] 
kNNIPNCF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIPNCs = at.testKNNByDir(fileName, 'IPNC_KNN', i)
    kNNIPNCPrecisions.append(kNNIPNCs[0])
    kNNIPNCRecalls.append(kNNIPNCs[1])
    kNNIPNCF_measures.append(kNNIPNCs[2])
# Out:
# 正确率：0.7774074074074073
# 召回率：0.9789473684210528
# 准确率：0.9488958660387231
# f-measure：0.8666141330284902
# 正确率：0.7866666666666667
# 召回率：0.9789473684210528
# 准确率：0.955018315018315
# f-measure：0.8723370429252782
# 正确率：0.7825279371791
# 召回率：0.9689473684210526
# 准确率：0.958079539508111
# f-measure：0.8658168151401171
# 正确率：0.7724242424242425
# 召回率：0.9689473684210526
# 准确率：0.9550078492935636
# f-measure：0.8595964610199296
# 正确率：0.8146320346320346
# 召回率：0.958421052631579
# 准确率：0.9682940868655155
# f-measure：0.8806961255112805
# 正确率：0.8517748917748917
# 召回率：0.958421052631579
# 准确率：0.976473050758765
# f-measure：0.9019564880836255
# 正确率：0.8816558441558442
# 召回率：0.9278947368421052
# 准确率：0.9775091575091576
# f-measure：0.904184526355849
# 正确率：0.9149494949494951
# 召回率：0.8873684210526316
# 准确率：0.9805651491365778
# f-measure：0.9009479198621895

# %%
cp.createKNNPlotter(kValues, kNNPrecisions, kNNIPDCPrecisions, kNNIPDSPrecisions, kNNIPDCSPrecisions, 'precision')

# %%
cp.createKNNPlotter(kValues, kNNRecalls, kNNIPDCRecalls, kNNIPDSRecalls, kNNIPDCSRecalls, 'recall')

# %%
cp.createKNNPlotter(kValues, kNNF_measures, kNNIPDCF_measures, kNNIPDSF_measures, kNNIPDCSF_measures, 'F-measure')

# %%
precisions.append(kNNIPDCPrecisions[3])
recalls.append(kNNIPDCRecalls[3])
f_measures.append(kNNIPDCF_measures[3])
precisions.append(kNNIPDSPrecisions[3])
recalls.append(kNNIPDSRecalls[3])
f_measures.append(kNNIPDSF_measures[3])
precisions.append(kNNIPDCSPrecisions[3])
recalls.append(kNNIPDCSRecalls[3])
f_measures.append(kNNIPDCSF_measures[3])
precisions.append(kNNPrecisions[3])
recalls.append(kNNRecalls[3])
f_measures.append(kNNF_measures[3])

# %%
SVMs = at.testOthersByDir(fileName, 'SVM', 0)
precisions.append(SVMs[0])
recalls.append(SVMs[1])
f_measures.append(SVMs[2])
# cp.createROCPlotter(SVMs[3], SVMs[4], 'ecoli-SVM')
# Out:
# 正确率：0.7583703703703704
# 召回率：0.7968421052631578
# 准确率：0.948880167451596
# f-measure：0.7771303946735119

# %%
RFs = at.testOthersByDir(fileName, 'RF')
precisions.append(RFs[0])
recalls.append(RFs[1])
f_measures.append(RFs[2])
# cp.createROCPlotter(RFs[3], RFs[4], 'ecoli-RF')
# Out:
# 正确率：0.9484848484848485
# 召回率：0.7631578947368421
# 准确率：0.9733908948194662
# f-measure：0.8457882966828176

# %%
bayes = at.testOthersByDir(fileName, 'Bayes', 0)
precisions.append(bayes[0])
recalls.append(bayes[1])
f_measures.append(bayes[2])
# Out:
# 正确率：0.43572034271617993
# 召回率：0.8978947368421053
# 准确率：0.8659863945578232
# f-measure：0.5867225235477667

# %%
trees = at.testOthersByDir(fileName, 'Tree')
precisions.append(trees[0])
recalls.append(trees[1])
f_measures.append(trees[2])
# Out:
# 正确率：0.7922857142857144
# 召回率：0.8363157894736842
# 准确率：0.9590947148090005
# f-measure：0.813705564070839

# %%
cp.createClassPlotter(precisions, recalls, f_measures)

# %%
'''kNNs = at.testKNNByDir(fileName, 'KNN', 6)
kNNIPDCs = at.testKNNByDir(fileName, 'IPDC_KNN', 6)
kNNIPDSs = at.testKNNByDir(fileName, 'IPDS_KNN', 6)
kNNIPDCSs = at.testKNNByDir(fileName, 'IPDCS_KNN', 6)
cp.createROCPlotter(kNNs[3], kNNs[4], 'ecoli-KNN')
cp.createROCPlotter(kNNIPDCs[3], kNNIPDCs[4], 'ecoli-IPDC_KNN')
cp.createROCPlotter(kNNIPDSs[3], kNNIPDSs[4], 'ecoli-IPDS_KNN')
cp.createROCPlotter(kNNIPDCSs[3], kNNIPDCSs[4], 'ecoli-IPDCS_KNN')'''
# Out:
# "kNNs = at.testKNNByDir(fileName, 'KNN', 6)\nkNNIPDCs = at.testKNNByDir(fileName, 'IPDC_KNN', 6)\nkNNIPDSs = at.testKNNByDir(fileName, 'IPDS_KNN', 6)\nkNNIPDCSs = at.testKNNByDir(fileName, 'IPDCS_KNN', 6)\ncp.createROCPlotter(kNNs[3], kNNs[4], 'ecoli-KNN')\ncp.createROCPlotter(kNNIPDCs[3], kNNIPDCs[4], 'ecoli-IPDC_KNN')\ncp.createROCPlotter(kNNIPDSs[3], kNNIPDSs[4], 'ecoli-IPDS_KNN')\ncp.createROCPlotter(kNNIPDCSs[3], kNNIPDCSs[4], 'ecoli-IPDCS_KNN')"
