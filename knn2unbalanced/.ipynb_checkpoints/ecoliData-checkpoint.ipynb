# %%
import kNN
from imp import reload
import createPlotter as cp
fileName = 'ecoli.dat'
file = 'ecoli'

# %%
dataMat, labels, features = kNN.file2matrix(fileName)

# %%
cp.createIRPlotter(dataMat, labels, features, file)

# %%
precisions = []
recalls = []
f_measures = []

# %%
kValues = []
kNNPrecisions = []
kNNRecalls = [] 
kNNF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNPrecision, kNNRecall, kNNF_measure = kNN.testKNN(fileName, i)
    kNNPrecisions.append(kNNPrecision)
    kNNRecalls.append(kNNRecall)
    kNNF_measures.append(kNNF_measure)
# Out:
# 正确率：0.6342857142857142
# 召回率：0.6400000000000001
# 准确率：0.9179999999999999
# f-measure：0.6371300448430492
# 正确率：0.6342857142857142
# 召回率：0.6966666666666667
# 准确率：0.9279999999999999
# f-measure：0.6640143112701251
# 正确率：0.5926190476190476
# 召回率：0.6583333333333334
# 准确率：0.9219999999999999
# f-measure：0.6237501586093136
# 正确率：0.6511904761904762
# 召回率：0.7459523809523809
# 准确率：0.9360000000000002
# f-measure：0.695357792060246
# 正确率：0.6369047619047619
# 召回率：0.7559523809523809
# 准确率：0.9340000000000002
# f-measure：0.6913410663410663
# 正确率：0.7614285714285713
# 召回率：0.7492857142857142
# 准确率：0.9460000000000001
# f-measure：0.7553083417764268
# 正确率：0.7064285714285715
# 召回率：0.7083333333333333
# 准确率：0.9400000000000001
# f-measure：0.7073796701447324
# 正确率：0.798095238095238
# 召回率：0.7579761904761904
# 准确率：0.9500000000000002
# f-measure：0.7775185343053141

# %%
kValues = []
kNNIPPrecisions = []
kNNIPRecalls = [] 
kNNIPF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIPPrecision, kNNIPRecall, kNNIPF_measure = kNN.testIPKNN(fileName, i)
    kNNIPPrecisions.append(kNNIPPrecision)
    kNNIPRecalls.append(kNNIPRecall)
    kNNIPF_measures.append(kNNIPF_measure)
# Out:
# 正确率：0.93
# 召回率：0.7488636363636364
# 准确率：0.952
# f-measure：0.8296602138892649
# 正确率：0.93
# 召回率：0.7488636363636364
# 准确率：0.952
# f-measure：0.8296602138892649
# 正确率：0.95
# 召回率：0.7384615384615385
# 准确率：0.9480000000000001
# f-measure：0.8309794988610478
# 正确率：0.95
# 召回率：0.7384615384615385
# 准确率：0.9480000000000001
# f-measure：0.8309794988610478
# 正确率：0.95
# 召回率：0.7325
# 准确率：0.944
# f-measure：0.8271916790490341
# 正确率：0.95
# 召回率：0.7442948717948717
# 准确率：0.95
# f-measure：0.8346600582649162
# 正确率：0.95
# 召回率：0.7498504273504273
# 准确率：0.952
# f-measure：0.8381418676856939
# 正确率：0.95
# 召回率：0.7408333333333333
# 准确率：0.95
# f-measure：0.8324790537210447

# %%
kValues = []
kNNIP2Precisions = []
kNNIP2Recalls = [] 
kNNIP2F_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIP2Precision, kNNIP2Recall, kNNIP2F_measure = kNN.testIP2KNN(fileName, i)
    kNNIP2Precisions.append(kNNIP2Precision)
    kNNIP2Recalls.append(kNNIP2Recall)
    kNNIP2F_measures.append(kNNIP2F_measure)
# Out:
# 正确率：0.8390476190476189
# 召回率：0.8333333333333333
# 准确率：0.966
# f-measure：0.836180713743356
# 正确率：0.8390476190476189
# 召回率：0.8583333333333332
# 准确率：0.97
# f-measure：0.8485809136391264
# 正确率：0.8390476190476189
# 召回率：0.8733333333333334
# 准确率：0.9720000000000001
# f-measure：0.8558472376714868
# 正确率：0.819047619047619
# 召回率：0.8733333333333334
# 准确率：0.97
# f-measure：0.8453198274244983
# 正确率：0.8390476190476189
# 召回率：0.9233333333333335
# 准确率：0.976
# f-measure：0.8791749977483563
# 正确率：0.8590476190476191
# 召回率：0.9
# 准确率：0.976
# f-measure：0.8790471034109366
# 正确率：0.8590476190476191
# 召回率：0.9
# 准确率：0.976
# f-measure：0.8790471034109366
# 正确率：0.8590476190476191
# 召回率：0.9
# 准确率：0.976
# f-measure：0.8790471034109366

# %%
kValues = []
kNNIP3Precisions = []
kNNIP3Recalls = [] 
kNNIP3F_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIP3Precision, kNNIP3Recall, kNNIP3F_measure = kNN.testIP3KNN(fileName, i)
    kNNIP3Precisions.append(kNNIP3Precision)
    kNNIP3Recalls.append(kNNIP3Recall)
    kNNIP3F_measures.append(kNNIP3F_measure)
# Out:
# 正确率：0.93
# 召回率：0.7844444444444444
# 准确率：0.96
# f-measure：0.8510434219053792
# 正确率：0.93
# 召回率：0.7989285714285714
# 准确率：0.9640000000000001
# f-measure：0.8594959719066309
# 正确率：0.93
# 召回率：0.8136904761904763
# 准确率：0.968
# f-measure：0.8679661364101864
# 正确率：0.93
# 召回率：0.7992063492063493
# 准确率：0.9640000000000001
# f-measure：0.8596566917569305
# 正确率：0.93
# 召回率：0.7850396825396826
# 准确率：0.96
# f-measure：0.8513936000370209
# 正确率：0.93
# 召回率：0.7850396825396826
# 准确率：0.96
# f-measure：0.8513936000370209
# 正确率：0.93
# 召回率：0.7850396825396826
# 准确率：0.96
# f-measure：0.8513936000370209
# 正确率：0.93
# 召回率：0.7992063492063493
# 准确率：0.9640000000000001
# f-measure：0.8596566917569305

# %%
reload(kNN)
kValues = []
kNNIP4Precisions = []
kNNIP4Recalls = [] 
kNNIP4F_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNPrecision, kNNRecall, kNNF_measure = kNN.testIP4KNN(fileName, i)
    kNNIP4Precisions.append(kNNPrecision)
    kNNIP4Recalls.append(kNNRecall)
    kNNIP4F_measures.append(kNNF_measure)
# Out:
# 正确率：0.6747619047619049
# 召回率：0.9
# 准确率：0.968
# f-measure：0.7712730571514969
# 正确率：0.6747619047619049
# 召回率：0.9
# 准确率：0.968
# f-measure：0.7712730571514969
# 正确率：0.6747619047619049
# 召回率：0.9
# 准确率：0.968
# f-measure：0.7712730571514969
# 正确率：0.6747619047619049
# 召回率：0.9
# 准确率：0.968
# f-measure：0.7712730571514969
# 正确率：0.6747619047619049
# 召回率：0.9
# 准确率：0.968
# f-measure：0.7712730571514969
# 正确率：0.6747619047619049
# 召回率：0.9
# 准确率：0.968
# f-measure：0.7712730571514969
# 正确率：0.6747619047619049
# 召回率：0.9
# 准确率：0.968
# f-measure：0.7712730571514969
# 正确率：0.6747619047619049
# 召回率：0.9
# 准确率：0.968
# f-measure：0.7712730571514969

# %%
reload(cp)
# Out:
# <module 'createPlotter' from 'F:\\pythonCode\\knn2unbalanced\\createPlotter.py'>

# %%
cp.createKNNPlotter(kValues, kNNPrecisions, kNNIPPrecisions, kNNIP2Precisions, kNNIP3Precisions, 'precision')

# %%
cp.createKNNPlotter(kValues, kNNRecalls, kNNIPRecalls, kNNIP2Recalls, kNNIP3Recalls, 'recall')

# %%
cp.createKNNPlotter(kValues, kNNF_measures, kNNIPF_measures, kNNIP2F_measures, kNNIP3F_measures, 'F-measure')

# %%
precisions.append(kNNIPPrecisions[3])
recalls.append(kNNIPRecalls[3])
f_measures.append(kNNIPF_measures[3])
precisions.append(kNNIP2Precisions[3])
recalls.append(kNNIP2Recalls[3])
f_measures.append(kNNIP2F_measures[3])
precisions.append(kNNIP3Precisions[3])
recalls.append(kNNIP3Recalls[3])
f_measures.append(kNNIP3F_measures[3])
precisions.append(kNNPrecisions[3])
recalls.append(kNNRecalls[3])
f_measures.append(kNNF_measures[3])

# %%
SVMs = kNN.testSVM(fileName)
precisions.append(SVMs[0])
recalls.append(SVMs[1])
f_measures.append(SVMs[2])
# Out:
# 正确率：0.23833333333333334
# 召回率：0.6266666666666666
# 准确率：0.906
# f-measure：0.34533076429030185

# %%
RFs = kNN.testRandomForest(fileName)
precisions.append(RFs[0])
recalls.append(RFs[1])
f_measures.append(RFs[2])
# Out:
# 正确率：0.8057142857142857
# 召回率：0.9314285714285715
# 准确率：0.974
# f-measure：0.8640225563909775

# %%
bayes = kNN.testBayes(fileName)
precisions.append(bayes[0])
recalls.append(bayes[1])
f_measures.append(bayes[2])
# Out:
# 正确率：0.95
# 召回率：0.3446361494542609
# 准确率：0.79
# f-measure：0.5057858798698945

# %%
trees = kNN.testDecisionTree(fileName)
precisions.append(trees[0])
recalls.append(trees[1])
f_measures.append(trees[2])
# Out:
# 正确率：0.8357142857142857
# 召回率：0.8933333333333333
# 准确率：0.9719999999999999
# f-measure：0.8635637565408979

# %%
reload(cp)
cp.createClassPlotter(precisions, recalls, f_measures)
