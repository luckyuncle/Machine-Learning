# %%
import kNN
from imp import reload
import createPlotter as cp

# %%
dataMat, labels = kNN.file2matrix('ecoli.dat')

# %%
features = ['Mcg', 'Gvh', 'Lip', 'Chg', 'Aac', 'Alm1', 'Alm2']

# %%
cp.createIRPlotter(dataMat, labels, features, 'ecoli')

# %%
precisions = []
recalls = []
f_measures = []

# %%
kValues = []
kNNPrecisions = []
kNNRecalls = [] 
kNNF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNPrecision, kNNRecall, kNNF_measure = kNN.testKNN('ecoli.dat', i)
    kNNPrecisions.append(kNNPrecision)
    kNNRecalls.append(kNNRecall)
    kNNF_measures.append(kNNF_measure)
# Out:
# 正确率：0.5592952380952375
# 召回率：0.508914285714286
# 准确率：0.9086660174080923
# f-measure：0.5329166802100023
# 正确率：0.5592952380952375
# 召回率：0.5411809523809524
# 准确率：0.9185884557789128
# f-measure：0.5500890109826706
# 正确率：0.5035285714285711
# 召回率：0.5064476190476193
# 准确率：0.9107559027141255
# f-measure：0.5049838769015231
# 正确率：0.5820190476190491
# 召回率：0.600819047619047
# 准确率：0.9318866175629616
# f-measure：0.5912696442470131
# 正确率：0.5815619047619065
# 召回率：0.592619047619047
# 准确率：0.9284074936412566
# f-measure：0.5870384141944466
# 正确率：0.6710095238095245
# 召回率：0.6061190476190478
# 准确率：0.9363899769043824
# f-measure：0.6369157540024333
# 正确率：0.6402428571428573
# 召回率：0.5879857142857134
# 准确率：0.9325058841818263
# f-measure：0.6130025997288275
# 正确率：0.7451761904761898
# 召回率：0.6342238095238101
# 准确率：0.9448621950830973
# f-measure：0.6852377588665353

# %%
kValues = []
kNNIPPrecisions = []
kNNIPRecalls = [] 
kNNIPF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIPPrecision, kNNIPRecall, kNNIPF_measure = kNN.testIPKNN('ecoli.dat', i)
    kNNIPPrecisions.append(kNNIPPrecision)
    kNNIPRecalls.append(kNNIPRecall)
    kNNIPF_measures.append(kNNIPF_measure)
# Out:
# 正确率：0.8546666666666662
# 召回率：0.6629099567099573
# 准确率：0.949781366518887
# f-measure：0.7466733926631338
# 正确率：0.8546666666666662
# 召回率：0.6629099567099573
# 准确率：0.949781366518887
# f-measure：0.7466733926631338
# 正确率：0.856666666666666
# 召回率：0.6543251581751584
# 准确率：0.9433823093960094
# f-measure：0.7419478291733722
# 正确率：0.856666666666666
# 召回率：0.6543251581751584
# 准确率：0.9433823093960094
# f-measure：0.7419478291733722
# 正确率：0.856666666666666
# 召回率：0.6484846653346659
# 准确率：0.9443464232023369
# f-measure：0.7381785270694696
# 正确率：0.856666666666666
# 召回率：0.6580201742701749
# 准确率：0.9507322864760782
# f-measure：0.7443174840586796
# 正确率：0.856666666666666
# 召回率：0.6636241425241428
# 准确率：0.9529692391662794
# f-measure：0.7478893888706395
# 正确率：0.856666666666666
# 召回率：0.6546791486291494
# 准确率：0.9498463330544574
# f-measure：0.7421753490382091

# %%
kValues = []
kNNIP2Precisions = []
kNNIP2Recalls = [] 
kNNIP2F_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIP2Precision, kNNIP2Recall, kNNIP2F_measure = kNN.testIP2KNN('ecoli.dat', i)
    kNNIP2Precisions.append(kNNIP2Precision)
    kNNIP2Recalls.append(kNNIP2Recall)
    kNNIP2F_measures.append(kNNIP2F_measure)
# Out:
# 正确率：0.7809999999999995
# 召回率：0.7479333333333338
# 准确率：0.9749581129234647
# f-measure：0.7641090956658236
# 正确率：0.7809999999999995
# 召回率：0.7607666666666667
# 准确率：0.9776184790491206
# f-measure：0.7707505675307545
# 正确率：0.7797999999999995
# 召回率：0.778066666666667
# 准确率：0.9790649733702724
# f-measure：0.7789323690516945
# 正确率：0.7719999999999994
# 召回率：0.778066666666667
# 准确率：0.9783029826745043
# f-measure：0.7750214614425185
# 正确率：0.7797999999999995
# 召回率：0.7987333333333337
# 准确率：0.9811485128665752
# f-measure：0.7891531210406285
# 正确率：0.7887999999999995
# 召回率：0.7879333333333332
# 准确率：0.9808354004808586
# f-measure：0.7883664284808249
# 正确率：0.7887999999999995
# 召回率：0.7879333333333332
# 准确率：0.9808354004808586
# f-measure：0.7883664284808249
# 正确率：0.7887999999999995
# 召回率：0.7879333333333332
# 准确率：0.9808354004808586
# f-measure：0.7883664284808249

# %%
kValues = []
kNNIP3Precisions = []
kNNIP3Recalls = [] 
kNNIP3F_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIP3Precision, kNNIP3Recall, kNNIP3F_measure = kNN.testIP3KNN('ecoli.dat', i)
    kNNIP3Precisions.append(kNNIP3Precision)
    kNNIP3Recalls.append(kNNIP3Recall)
    kNNIP3F_measures.append(kNNIP3F_measure)
# Out:
# 正确率：0.8546666666666662
# 召回率：0.7156460317460324
# 准确率：0.9578638366073566
# f-measure：0.779002563099521
# 正确率：0.8546666666666662
# 召回率：0.7265928571428574
# 准确率：0.9655575333075502
# f-measure：0.7854431051798672
# 正确率：0.8546666666666662
# 召回率：0.7298523809523807
# 准确率：0.9690952054767181
# f-measure：0.787343645410404
# 正确率：0.8546666666666662
# 召回率：0.7065841269841273
# 准确率：0.9629627419877586
# f-measure：0.7736026818817093
# 正确率：0.8546666666666662
# 召回率：0.701898412698413
# 准确率：0.9617493836515977
# f-measure：0.7707858600608856
# 正确率：0.8546666666666662
# 召回率：0.701898412698413
# 准确率：0.9617493836515977
# f-measure：0.7707858600608856
# 正确率：0.8546666666666662
# 召回率：0.701898412698413
# 准确率：0.9617493836515977
# f-measure：0.7707858600608856
# 正确率：0.8546666666666662
# 召回率：0.7065841269841273
# 准确率：0.9629627419877586
# f-measure：0.7736026818817093

# %%
reload(cp)
# Out:
# <module 'createPlotter' from 'F:\\pythonCode\\knn2unbalanced\\createPlotter.py'>

# %%
cp.createKNNPlotter(kValues, kNNPrecisions, kNNIPPrecisions, kNNIP2Precisions, kNNIP3Precisions, 'precision')

# %%
cp.createKNNPlotter(kValues, kNNRecalls, kNNIPRecalls, kNNIP2Recalls, kNNIP3Recalls, 'recall')

# %%
cp.createKNNPlotter(kValues, kNNF_measures, kNNIPF_measures, kNNIP2F_measures, kNNIP3F_measures, 'F-measure')

# %%
precisions.append(kNNIPPrecisions[3])
recalls.append(kNNIPRecalls[3])
f_measures.append(kNNIPF_measures[3])
precisions.append(kNNIP2Precisions[3])
recalls.append(kNNIP2Recalls[3])
f_measures.append(kNNIP2F_measures[3])
precisions.append(kNNIP3Precisions[3])
recalls.append(kNNIP3Recalls[3])
f_measures.append(kNNIP3F_measures[3])
precisions.append(kNNPrecisions[3])
recalls.append(kNNRecalls[3])
f_measures.append(kNNF_measures[3])

# %%
SVMs = kNN.testSVM('ecoli.dat')
precisions.append(SVMs[0])
recalls.append(SVMs[1])
f_measures.append(SVMs[2])
# Out:
# 正确率：0.0
# 召回率：0.0
# 准确率：0.8920000000000001
# f-measure：0

# %%
RFs = kNN.testRandomForest('ecoli.dat')
precisions.append(RFs[0])
recalls.append(RFs[1])
f_measures.append(RFs[2])
# Out:
# 正确率：0.7457142857142858
# 召回率：0.95
# 准确率：0.9739999999999999
# f-measure：0.8355518112889637

# %%
bayes = kNN.testBayes('ecoli.dat')
precisions.append(bayes[0])
recalls.append(bayes[1])
f_measures.append(bayes[2])
# Out:
# 正确率：0.0
# 召回率：0.0
# 准确率：0.8920000000000001
# f-measure：0

# %%
trees = kNN.testDecisionTree('ecoli.dat')
precisions.append(trees[0])
recalls.append(trees[1])
f_measures.append(trees[2])
# Out:
# 正确率：0.8357142857142857
# 召回率：0.8766666666666666
# 准确率：0.97
# f-measure：0.8557007786429366

# %%
reload(cp)
cp.createClassPlotter(precisions, recalls, f_measures)
