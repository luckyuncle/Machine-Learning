# %%
import algorithmTest as at
import createPlotter as cp
import dataTreat as dt
from imp import reload
fileName = 'haberman-5-fold'
file = 'haberman-5-fold'

# %%
dataMat, labels, features, length = dt.createIR(fileName)

# %%
print(length)
cp.createIRPlotter(dataMat, labels, features, file)
# Out:
# 1530

# %%
precisions = []
recalls = []
f_measures = []

# %%
kValues = []
kNNPrecisions = []
kNNRecalls = [] 
kNNF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNs = at.testKNNByDir(fileName, 'KNN', i)
    kNNPrecisions.append(kNNs[0])
    kNNRecalls.append(kNNs[1])
    kNNF_measures.append(kNNs[2])
# Out:
# 正确率：0.44742937007087946
# 召回率：0.30398190045248874
# 准确率：0.7136457332800916
# f-measure：0.36201328238708136
# 正确率：0.4891835016835017
# 召回率：0.328789592760181
# 准确率：0.7152650039391748
# f-measure：0.39326096517369385
# 正确率：0.4190863787375415
# 召回率：0.24567873303167423
# 准确率：0.7087471265608306
# f-measure：0.30976538550601934
# 正确率：0.4322728950635927
# 召回率：0.24494343891402717
# 准确率：0.7152650039391748
# f-measure：0.31269892397396876
# 正确率：0.43264614789005035
# 召回率：0.22013574660633486
# 准确率：0.7201234634520123
# f-measure：0.2918000134045029
# 正确率：0.45773216825848406
# 召回率：0.23010180995475116
# 准确率：0.7267598398428647
# f-measure：0.30625122842692165
# 正确率：0.5401954887218045
# 召回率：0.26016968325791856
# 准确率：0.7462733247714739
# f-measure：0.35119591436112363
# 正确率：0.5225797251750065
# 召回率：0.2701357466063349
# 准确率：0.7414014828564953
# f-measure：0.3561617484373324

# %%
kValues = []
kNNIPDCPrecisions = []
kNNIPDCRecalls = [] 
kNNIPDCF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIPDCs = at.testKNNByDir(fileName, 'IPDC_KNN', i)
    kNNIPDCPrecisions.append(kNNIPDCs[0])
    kNNIPDCRecalls.append(kNNIPDCs[1])
    kNNIPDCF_measures.append(kNNIPDCs[2])
# Out:
# 正确率：0.39679487179487183
# 召回率：0.39212669683257917
# 准确率：0.6833740921011451
# f-measure：0.394446973145198
# 正确率：0.4225659256837747
# 召回率：0.40462669683257924
# 准确率：0.6939602197304093
# f-measure：0.41340178828794266
# 正确率：0.4077228327228327
# 召回率：0.38289592760180996
# 准确率：0.6890883778154308
# f-measure：0.3949195745766082
# 正确率：0.4245074734669017
# 召回率：0.388314479638009
# 准确率：0.7045463473596736
# f-measure：0.40560518335426815
# 正确率：0.4204551156605952
# 召回率：0.3765497737556561
# 准确率：0.7030060760422625
# f-measure：0.39729311771817355
# 正确率：0.4408055712403539
# 召回率：0.3765497737556561
# 准确率：0.7127758771409145
# f-measure：0.4061519610460204
# 正确率：0.4647511312217194
# 召回率：0.40081447963800904
# 准确率：0.7225456782395667
# f-measure：0.43042140418861313
# 正确率：0.46060988799336255
# 召回率：0.3890497737556561
# 准确率：0.7234015044410149
# f-measure：0.42181635961051384

# %%
kValues = []
kNNIPDSPrecisions = []
kNNIPDSRecalls = [] 
kNNIPDSF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIPDSs = at.testKNNByDir(fileName, 'IPDS_KNN', i)
    kNNIPDSPrecisions.append(kNNIPDSs[0])
    kNNIPDSRecalls.append(kNNIPDSs[1])
    kNNIPDSF_measures.append(kNNIPDSs[2])
# Out:
# 正确率：0.3999349406812093
# 召回率：0.3588235294117647
# 准确率：0.6899709688211615
# f-measure：0.37826547605519806
# 正确率：0.4167754975124378
# 召回率：0.36824660633484163
# 准确率：0.6924333308151394
# f-measure：0.3910110602244346
# 正确率：0.4071056062581486
# 召回率：0.35266968325791853
# 准确率：0.6899575864190203
# f-measure：0.3779375486218625
# 正确率：0.3830616864742501
# 召回率：0.3215158371040724
# 准确率：0.680937847375862
# f-measure：0.3496007030249112
# 正确率：0.40486803519061587
# 召回率：0.3245927601809955
# 准确率：0.6972650255236944
# f-measure：0.3603133544267588
# 正确率：0.4221383879278616
# 召回率：0.3215158371040724
# 准确率：0.7054416732319579
# f-measure：0.36501958195036627
# 正确率：0.44301165501165507
# 召回率：0.3215158371040724
# 准确率：0.714434647470834
# f-measure：0.37260991809140126
# 正确率：0.4255163883735313
# 召回率：0.30667420814479635
# 准确率：0.7079301524946309
# f-measure：0.35645063478719474

# %%
kValues = []
kNNIPDCSPrecisions = []
kNNIPDCSRecalls = [] 
kNNIPDCSF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIPDCSs = at.testKNNByDir(fileName, 'IPDCS_KNN', i)
    kNNIPDCSPrecisions.append(kNNIPDCSs[0])
    kNNIPDCSRecalls.append(kNNIPDCSs[1])
    kNNIPDCSF_measures.append(kNNIPDCSs[2])
# Out:
# 正确率：0.38026436307297945
# 召回率：0.3742081447963801
# 准确率：0.674407235130964
# f-measure：0.3772119470318893
# 正确率：0.39884920634920634
# 召回率：0.371131221719457
# 准确率：0.6850596272353469
# f-measure：0.38449131390393354
# 正确率：0.3796608946608947
# 召回率：0.35555429864253396
# 准确率：0.6768562147228009
# f-measure：0.36721238721039323
# 正确率：0.38628815628815627
# 召回率：0.3463235294117647
# 准确率：0.6825972652413689
# f-measure：0.36521578966588975
# 正确率：0.4071024129113937
# 召回率：0.3463235294117647
# 准确率：0.6948294283339989
# f-measure：0.37426145438205943
# 正确率：0.4130158494671513
# 召回率：0.36116515837104074
# 准确率：0.6972784079258356
# f-measure：0.38535415664376593
# 正确率：0.42907853172209354
# 召回率：0.3642420814479638
# 准确率：0.7045858470305097
# f-measure：0.3940108322020603
# 正确率：0.4207518470230335
# 召回率：0.36190045248868785
# 准确率：0.701412922651874
# f-measure：0.38911348990627104

# %%
kValues = []
kNNIPNCPrecisions = []
kNNIPNCRecalls = [] 
kNNIPNCF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIPNCs = at.testKNNByDir(fileName, 'IPNC_KNN', i)
    kNNIPNCPrecisions.append(kNNIPNCs[0])
    kNNIPNCRecalls.append(kNNIPNCs[1])
    kNNIPNCF_measures.append(kNNIPNCs[2])
# Out:
# 正确率：0.5682352941176471
# 召回率：0.14138009049773756
# 准确率：0.7496437475042899
# f-measure：0.22642450839733308
# 正确率：0.5492063492063491
# 召回率：0.14138009049773756
# 准确率：0.7480110944430653
# f-measure：0.22487219235291395
# 正确率：0.58
# 召回率：0.14138009049773756
# 准确率：0.7504600740349022
# f-measure：0.2273432648580837
# 正确率：0.58
# 召回率：0.14138009049773756
# 准确率：0.7504600740349022
# f-measure：0.2273432648580837
# 正确率：0.5894736842105263
# 召回率：0.14138009049773756
# 准确率：0.7512764005655144
# f-measure：0.2280616060387343
# 正确率：0.5999999999999999
# 召回率：0.14138009049773756
# 准确率：0.7520927270961267
# f-measure：0.22883823125514965
# 正确率：0.5999999999999999
# 召回率：0.14138009049773756
# 准确率：0.7520927270961267
# f-measure：0.22883823125514965
# 正确率：0.5999999999999999
# 召回率：0.14138009049773756
# 准确率：0.7520927270961267
# f-measure：0.22883823125514965

# %%
cp.createKNNPlotter(kValues, kNNPrecisions, kNNIPDCPrecisions, kNNIPDSPrecisions, kNNIPDCSPrecisions, 'precision')

# %%
cp.createKNNPlotter(kValues, kNNRecalls, kNNIPDCRecalls, kNNIPDSRecalls, kNNIPDCSRecalls, 'recall')

# %%
cp.createKNNPlotter(kValues, kNNF_measures, kNNIPDCF_measures, kNNIPDSF_measures, kNNIPDCSF_measures, 'F-measure')

# %%
precisions.append(kNNIPDCPrecisions[3])
recalls.append(kNNIPDCRecalls[3])
f_measures.append(kNNIPDCF_measures[3])
precisions.append(kNNIPDSPrecisions[3])
recalls.append(kNNIPDSRecalls[3])
f_measures.append(kNNIPDSF_measures[3])
precisions.append(kNNIPDCSPrecisions[3])
recalls.append(kNNIPDCSRecalls[3])
f_measures.append(kNNIPDCSF_measures[3])
precisions.append(kNNPrecisions[3])
recalls.append(kNNRecalls[3])
f_measures.append(kNNF_measures[3])

# %%
SVMs = at.testOthersByDir(fileName, 'SVM', 1)
precisions.append(SVMs[0])
recalls.append(SVMs[1])
f_measures.append(SVMs[2])
# Out:
# 正确率：0.4188725490196078
# 召回率：0.10173076923076922
# 准确率：0.7479715947722293
# f-measure：0.16370324632054697

# %%
RFs = at.testOthersByDir(fileName, 'RF')
precisions.append(RFs[0])
recalls.append(RFs[1])
f_measures.append(RFs[2])
# Out:
# 正确率：0.4809007013658177
# 召回率：0.29455882352941176
# 准确率：0.7151318274533505
# f-measure：0.3653409115012746

# %%
bayes = at.testOthersByDir(fileName, 'Bayes', 0)
precisions.append(bayes[0])
recalls.append(bayes[1])
f_measures.append(bayes[2])
# Out:
# 正确率：0.5207742257742257
# 召回率：0.4320022624434389
# 准确率：0.7429685189781889
# f-measure：0.47225271937084035

# %%
trees = at.testOthersByDir(fileName, 'Tree')
precisions.append(trees[0])
recalls.append(trees[1])
f_measures.append(trees[2])
# Out:
# 正确率：0.3795070422535211
# 召回率：0.41552036199095027
# 准确率：0.6697736863121769
# f-measure：0.39669803262984704

# %%
cp.createClassPlotter(precisions, recalls, f_measures)
