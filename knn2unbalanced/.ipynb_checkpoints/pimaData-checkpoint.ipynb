# %%
import algorithmTest as at
import createPlotter as cp
import dataTreat as dt
from imp import reload
fileName = 'pima.dat'
file = 'pima'

# %%
dataMat, labels, features = dt.file2matrix(fileName)

# %%
cp.createIRPlotter(dataMat, labels, features, file)

# %%
precisions = []
recalls = []
f_measures = []

# %%
kValues = []
kNNPrecisions = []
kNNRecalls = [] 
kNNF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNs = at.testKNNByFile(fileName, 'KNN', i)
    kNNPrecisions.append(kNNs[0])
    kNNRecalls.append(kNNs[1])
    kNNF_measures.append(kNNs[2])
# Out:
# 正确率：0.6802689055172075
# 召回率：0.6272774921035886
# 准确率：0.7711111111111111
# f-measure：0.6526993975668313
# 正确率：0.7047662432017271
# 召回率：0.6419263775339717
# 准确率：0.7866666666666666
# f-measure：0.6718801819223753
# 正确率：0.6465884654348811
# 召回率：0.5840037539830683
# 准确率：0.7511111111111111
# f-measure：0.6137046620930621
# 正确率：0.68172755679866
# 召回率：0.610516908103122
# 准确率：0.7722222222222223
# f-measure：0.6441601592420787
# 正确率：0.6622363016352787
# 召回率：0.5686593683697565
# 准确率：0.7566666666666666
# f-measure：0.6118908144309266
# 正确率：0.6742468284403769
# 召回率：0.5625372922157976
# 准确率：0.7611111111111111
# f-measure：0.6133471134068372
# 正确率：0.6566619730329408
# 召回率：0.545942184167042
# 准确率：0.7477777777777778
# f-measure：0.5962052761429587
# 正确率：0.6622377595398841
# 召回率：0.5439031256029766
# 准确率：0.7511111111111111
# f-measure：0.5972655296622209

# %%
kValues = []
kNNIPDCPrecisions = []
kNNIPDCRecalls = [] 
kNNIPDCF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIPDCs = at.testKNNByFile(fileName, 'IPDC_KNN', i)
    kNNIPDCPrecisions.append(kNNIPDCs[0])
    kNNIPDCRecalls.append(kNNIPDCs[1])
    kNNIPDCF_measures.append(kNNIPDCs[2])
# Out:
# 正确率：0.7518565803080588
# 召回率：0.6967091445575124
# 准确率：0.8255555555555555
# f-measure：0.7232331207408292
# 正确率：0.7460357398197689
# 召回率：0.6872951949314736
# 准确率：0.8188888888888888
# f-measure：0.71546181944962
# 正确率：0.7350244577154593
# 召回率：0.6699396893021333
# 准确率：0.8133333333333332
# f-measure：0.7009745520932469
# 正确率：0.7377360169465433
# 召回率：0.6728010414965505
# 准确率：0.8166666666666667
# f-measure：0.703773867662869
# 正确率：0.7440615754321407
# 召回率：0.6899096321741565
# 准确率：0.821111111111111
# f-measure：0.7159631171091825
# 正确率：0.7470060093415356
# 召回率：0.6883708328401766
# 准确率：0.8222222222222222
# f-measure：0.716490796947039
# 正确率：0.7453302724986492
# 召回率：0.6864694844872153
# 准确率：0.82
# f-measure：0.7146900052727341
# 正确率：0.747615844862237
# 召回率：0.6888487300922674
# 准确率：0.8222222222222222
# f-measure：0.7170301785500285

# %%
kValues = []
kNNIPDSPrecisions = []
kNNIPDSRecalls = [] 
kNNIPDSF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIPDSs = at.testKNNByFile(fileName, 'IPDS_KNN', i)
    kNNIPDSPrecisions.append(kNNIPDSs[0])
    kNNIPDSRecalls.append(kNNIPDSs[1])
    kNNIPDSF_measures.append(kNNIPDSs[2])
# Out:
# 正确率：0.7322954204204204
# 召回率：0.693614420528073
# 准确率：0.8122222222222222
# f-measure：0.7124302660712458
# 正确率：0.7390243886230728
# 召回率：0.6891296813308514
# 准确率：0.8111111111111111
# f-measure：0.7132054617104109
# 正确率：0.7333360645202751
# 召回率：0.6704779915795661
# 准确率：0.8099999999999999
# f-measure：0.7004997414806449
# 正确率：0.7365252857899918
# 召回率：0.6745865862369412
# 准确率：0.8111111111111111
# f-measure：0.704196581529115
# 正确率：0.7343366822508902
# 召回率：0.6637717843169153
# 准确率：0.8088888888888889
# f-measure：0.6972734684364313
# 正确率：0.7486066535635502
# 召回率：0.6658774198527835
# 准确率：0.8122222222222222
# f-measure：0.7048227354806031
# 正确率：0.7286955156389973
# 召回率：0.6494347962085204
# 准确率：0.8011111111111111
# f-measure：0.6867858861077518
# 正确率：0.7254404180380412
# 召回率：0.6638660131397373
# 准确率：0.8022222222222222
# f-measure：0.6932887191561742

# %%
kValues = []
kNNIPDCSPrecisions = []
kNNIPDCSRecalls = [] 
kNNIPDCSF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIPDCSs = at.testKNNByFile(fileName, 'IPDCS_KNN', i)
    kNNIPDCSPrecisions.append(kNNIPDCSs[0])
    kNNIPDCSRecalls.append(kNNIPDCSs[1])
    kNNIPDCSF_measures.append(kNNIPDCSs[2])
# Out:
# 正确率：0.7450866220250159
# 召回率：0.6844925983574703
# 准确率：0.8177777777777777
# f-measure：0.7135054436155563
# 正确率：0.7418287457301395
# 召回率：0.6860344432356132
# 准确率：0.8155555555555555
# f-measure：0.7128415025836989
# 正确率：0.741213878170748
# 召回率：0.6811599477829027
# 准确率：0.8177777777777777
# f-measure：0.7099191469053392
# 正确率：0.7363277881685589
# 召回率：0.6884162479206549
# 准确率：0.8188888888888888
# f-measure：0.7115664292403092
# 正确率：0.7250019658003166
# 召回率：0.6778468526387771
# 准确率：0.8099999999999999
# f-measure：0.700631877384309
# 正确率：0.7372059587608886
# 召回率：0.6833916416137986
# 准确率：0.8155555555555555
# f-measure：0.7092795176230046
# 正确率：0.7207078288101427
# 召回率：0.6625431198732875
# 准确率：0.8055555555555556
# f-measure：0.6904025822233583
# 正确率：0.7347995448426483
# 召回率：0.6765685637773968
# 准确率：0.8133333333333332
# f-measure：0.7044827918133316

# %%
kValues = []
kNNIPNCPrecisions = []
kNNIPNCRecalls = [] 
kNNIPNCF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIPNCs = at.testKNNByFile(fileName, 'IPNC_KNN', i)
    kNNIPNCPrecisions.append(kNNIPNCs[0])
    kNNIPNCRecalls.append(kNNIPNCs[1])
    kNNIPNCF_measures.append(kNNIPNCs[2])
# Out:
# 正确率：0.8
# 召回率：0.3119488649241541
# 准确率：0.7577777777777779
# f-measure：0.4488679287538023
# 正确率：0.8
# 召回率：0.3119488649241541
# 准确率：0.7577777777777779
# f-measure：0.4488679287538023
# 正确率：0.8
# 召回率：0.30962328352880525
# 准确率：0.7566666666666667
# f-measure：0.44645535200976894
# 正确率：0.8
# 召回率：0.30962328352880525
# 准确率：0.7566666666666667
# f-measure：0.44645535200976894
# 正确率：0.8
# 召回率：0.30962328352880525
# 准确率：0.7566666666666667
# f-measure：0.44645535200976894
# 正确率：0.8
# 召回率：0.30962328352880525
# 准确率：0.7566666666666667
# f-measure：0.44645535200976894
# 正确率：0.8
# 召回率：0.30962328352880525
# 准确率：0.7566666666666667
# f-measure：0.44645535200976894
# 正确率：0.8
# 召回率：0.30962328352880525
# 准确率：0.7566666666666667
# f-measure：0.44645535200976894

# %%
cp.createKNNPlotter(kValues, kNNPrecisions, kNNIPDCPrecisions, kNNIPDSPrecisions, kNNIPDCSPrecisions, 'precision')

# %%
cp.createKNNPlotter(kValues, kNNRecalls, kNNIPDCRecalls, kNNIPDSRecalls, kNNIPDCSRecalls, 'recall')

# %%
cp.createKNNPlotter(kValues, kNNF_measures, kNNIPDCF_measures, kNNIPDSF_measures, kNNIPDCSF_measures, 'F-measure')

# %%
precisions.append(kNNIPDCPrecisions[3])
recalls.append(kNNIPDCRecalls[3])
f_measures.append(kNNIPDCF_measures[3])
precisions.append(kNNIPDSPrecisions[3])
recalls.append(kNNIPDSRecalls[3])
f_measures.append(kNNIPDSF_measures[3])
precisions.append(kNNIPDCSPrecisions[3])
recalls.append(kNNIPDCSRecalls[3])
f_measures.append(kNNIPDCSF_measures[3])
precisions.append(kNNPrecisions[3])
recalls.append(kNNRecalls[3])
f_measures.append(kNNF_measures[3])

# %%
SVMs = at.testOthersByFile(fileName, 'SVM', 0)
precisions.append(SVMs[0])
recalls.append(SVMs[1])
f_measures.append(SVMs[2])
# Out:
# 正确率：0.7080909349246944
# 召回率：0.5596886534688091
# 准确率：0.7711111111111112
# f-measure：0.6252040426106976

# %%
RFs = at.testOthersByFile(fileName, 'RF')
precisions.append(RFs[0])
recalls.append(RFs[1])
f_measures.append(RFs[2])
# Out:
# 正确率：0.7552389717468319
# 召回率：0.6512794520967767
# 准确率：0.8111111111111111
# f-measure：0.699417249547669

# %%
bayes = at.testOthersByFile(fileName, 'Bayes')
precisions.append(bayes[0])
recalls.append(bayes[1])
f_measures.append(bayes[2])
# Out:
# 正确率：0.642649028838545
# 召回率：0.6048689724443432
# 准确率：0.7522222222222222
# f-measure：0.6231869316774367

# %%
trees = at.testOthersByFile(fileName, 'Tree')
precisions.append(trees[0])
recalls.append(trees[1])
f_measures.append(trees[2])
# Out:
# 正确率：0.6879434697855751
# 召回率：0.6847956496795595
# 准确率：0.7855555555555556
# f-measure：0.6863659506085614

# %%
cp.createClassPlotter(precisions, recalls, f_measures)
