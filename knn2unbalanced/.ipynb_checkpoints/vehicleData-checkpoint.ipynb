# %%
import algorithmTest as at
import createPlotter as cp
import dataTreat as dt
from imp import reload
fileName = 'vehicle.dat'
file = 'vehicle'

# %%
dataMat, labels, features = dt.file2matrix('vehicle.dat')

# %%
cp.createIRPlotter(dataMat, labels, features, 'vehicle')

# %%
precisions = []
recalls = []
f_measures = []

# %%
kValues = []
kNNPrecisions = []
kNNRecalls = [] 
kNNF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNs = at.testKNNByFile(fileName, 'KNN', i)
    kNNPrecisions.append(kNNs[0])
    kNNRecalls.append(kNNs[1])
    kNNF_measures.append(kNNs[2])
# Out:
# 正确率：0.6151138716356107
# 召回率：0.5516450094571692
# 准确率：0.7939999999999999
# f-measure：0.581653164221648
# 正确率：0.6198021509607188
# 召回率：0.5766198815636202
# 准确率：0.798
# f-measure：0.5974317308847725
# 正确率：0.5492053472842947
# 召回率：0.5113895486109642
# 准确率：0.7689999999999999
# f-measure：0.5296232816684797
# 正确率：0.6313663627668203
# 召回率：0.5582843156373103
# 准确率：0.8010000000000002
# f-measure：0.5925805686531994
# 正确率：0.5661644229149949
# 召回率：0.5222067675552249
# 准确率：0.7779999999999998
# f-measure：0.5432979038474439
# 正确率：0.6080155740521873
# 召回率：0.5698923421137577
# 准确率：0.798
# f-measure：0.5883370249621891
# 正确率：0.5419043035007498
# 召回率：0.45200338721572847
# 准确率：0.766
# f-measure：0.49288798752034463
# 正确率：0.5976677805625175
# 召回率：0.5015549379033952
# 准确率：0.7869999999999999
# f-measure：0.5454094452946648

# %%
kValues = []
kNNIPDCPrecisions = []
kNNIPDCRecalls = [] 
kNNIPDCF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIPDCs = at.testKNNByFile(fileName, 'IPDC_KNN', i)
    kNNIPDCPrecisions.append(kNNIPDCs[0])
    kNNIPDCRecalls.append(kNNIPDCs[1])
    kNNIPDCF_measures.append(kNNIPDCs[2])
# Out:
# 正确率：0.6442712547669445
# 召回率：0.7072384947511988
# 准确率：0.817
# f-measure：0.67428804356801
# 正确率：0.6373196516502804
# 召回率：0.699833732846437
# 准确率：0.813
# f-measure：0.6671153750976451
# 正确率：0.6437697677019145
# 召回率：0.7014835644962687
# 准确率：0.8160000000000001
# f-measure：0.6713886530569766
# 正确率：0.6502747252747252
# 召回率：0.722330108756606
# 准确率：0.82
# f-measure：0.6844111304049839
# 正确率：0.6639324776896037
# 召回率：0.7133459077724051
# 准确率：0.825
# f-measure：0.6877527753231945
# 正确率：0.6669452506671333
# 召回率：0.7073319753446794
# 准确率：0.825
# f-measure：0.6865451783264591
# 正确率：0.6629570973688621
# 召回率：0.7066378010642984
# 准确率：0.825
# f-measure：0.6841008914689166
# 正确率：0.6575159752528174
# 召回率：0.6873254244243354
# 准确率：0.819
# f-measure：0.6720903250969441

# %%
kValues = []
kNNIPDSPrecisions = []
kNNIPDSRecalls = [] 
kNNIPDSF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIPDSs = at.testKNNByFile(fileName, 'IPDS_KNN', i)
    kNNIPDSPrecisions.append(kNNIPDSs[0])
    kNNIPDSRecalls.append(kNNIPDSs[1])
    kNNIPDSF_measures.append(kNNIPDSs[2])
# Out:
# 正确率：0.6721331616023061
# 召回率：0.6509857962162863
# 准确率：0.827
# f-measure：0.6613904800977656
# 正确率：0.6708433048433049
# 召回率：0.6539942137247037
# 准确率：0.826
# f-measure：0.6623116171373092
# 正确率：0.6709706597750076
# 召回率：0.6154100903129942
# 准确率：0.8210000000000001
# f-measure：0.6419905060010553
# 正确率：0.682310572722472
# 召回率：0.6398171647200686
# 准确率：0.828
# f-measure：0.6603809960787406
# 正确率：0.6901415082502039
# 召回率：0.6477749457640566
# 准确率：0.8330000000000002
# f-measure：0.668287435639139
# 正确率：0.6981645021645022
# 召回率：0.6440062904091943
# 准确率：0.836
# f-measure：0.6699927216746596
# 正确率：0.6966288349331828
# 召回率：0.6180581644610682
# 准确率：0.8320000000000001
# f-measure：0.6549956593894014
# 正确率：0.7086156863731234
# 召回率：0.6270014969906077
# 准确率：0.836
# f-measure：0.6653150343993104

# %%
kValues = []
kNNIPDCSPrecisions = []
kNNIPDCSRecalls = [] 
kNNIPDCSF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIPDCSs = at.testKNNByFile(fileName, 'IPDCS_KNN', i)
    kNNIPDCSPrecisions.append(kNNIPDCSs[0])
    kNNIPDCSRecalls.append(kNNIPDCSs[1])
    kNNIPDCSF_measures.append(kNNIPDCSs[2])
# Out:
# 正确率：0.6542790456669766
# 召回率：0.6753980204107247
# 准确率：0.818
# f-measure：0.6646708189729299
# 正确率：0.6559384319384318
# 召回率：0.6814222369349411
# 准确率：0.8220000000000001
# f-measure：0.6684375336978075
# 正确率：0.659008337711486
# 召回率：0.6793176699619531
# 准确率：0.8210000000000001
# f-measure：0.6690089049945485
# 正确率：0.6602685418207997
# 召回率：0.6823878454005495
# 准确率：0.82
# f-measure：0.6711459937583857
# 正确率：0.6720683760683761
# 召回率：0.6825833146822257
# 准确率：0.825
# f-measure：0.6772850363855037
# 正确率：0.6683789008770076
# 召回率：0.672868324053442
# 准确率：0.8220000000000001
# f-measure：0.6706160989658183
# 正确率：0.6674658433354085
# 召回率：0.6669748490737601
# 准确率：0.8230000000000001
# f-measure：0.6672202558763419
# 正确率：0.6612069796507183
# 召回率：0.6719007749996859
# 准确率：0.8219999999999998
# f-measure：0.6665109860965799

# %%
kValues = []
kNNIPNCPrecisions = []
kNNIPNCRecalls = [] 
kNNIPNCF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIPNCs = at.testKNNByFile(fileName, 'IPNC_KNN', i)
    kNNIPNCPrecisions.append(kNNIPNCs[0])
    kNNIPNCRecalls.append(kNNIPNCs[1])
    kNNIPNCF_measures.append(kNNIPNCs[2])
# Out:
# 正确率：0.6
# 召回率：0.29582661154802714
# 准确率：0.8160000000000001
# f-measure：0.3962730390920082
# 正确率：0.6
# 召回率：0.29582661154802714
# 准确率：0.8160000000000001
# f-measure：0.3962730390920082
# 正确率：0.6
# 召回率：0.29582661154802714
# 准确率：0.8170000000000002
# f-measure：0.3962730390920082
# 正确率：0.6
# 召回率：0.29582661154802714
# 准确率：0.8170000000000002
# f-measure：0.3962730390920082
# 正确率：0.6
# 召回率：0.29582661154802714
# 准确率：0.8170000000000002
# f-measure：0.3962730390920082
# 正确率：0.6
# 召回率：0.29582661154802714
# 准确率：0.8170000000000002
# f-measure：0.3962730390920082
# 正确率：0.6
# 召回率：0.29582661154802714
# 准确率：0.8170000000000002
# f-measure：0.3962730390920082
# 正确率：0.6
# 召回率：0.29582661154802714
# 准确率：0.8170000000000002
# f-measure：0.3962730390920082

# %%
cp.createKNNPlotter(kValues, kNNPrecisions, kNNIPDCPrecisions, kNNIPDSPrecisions, kNNIPDCSPrecisions, 'precision')

# %%
cp.createKNNPlotter(kValues, kNNRecalls, kNNIPDCRecalls, kNNIPDSRecalls, kNNIPDCSRecalls, 'recall')

# %%
cp.createKNNPlotter(kValues, kNNF_measures, kNNIPDCF_measures, kNNIPDSF_measures, kNNIPDCSF_measures, 'F-measure')

# %%
precisions.append(kNNIPDCPrecisions[3])
recalls.append(kNNIPDCRecalls[3])
f_measures.append(kNNIPDCF_measures[3])
precisions.append(kNNIPDSPrecisions[3])
recalls.append(kNNIPDSRecalls[3])
f_measures.append(kNNIPDSF_measures[3])
precisions.append(kNNIPDCSPrecisions[3])
recalls.append(kNNIPDCSRecalls[3])
f_measures.append(kNNIPDCSF_measures[3])
precisions.append(kNNPrecisions[3])
recalls.append(kNNRecalls[3])
f_measures.append(kNNF_measures[3])

# %%
SVMs = at.testOthersByFile(fileName, 'SVM', 0)
precisions.append(SVMs[0])
recalls.append(SVMs[1])
f_measures.append(SVMs[2])
# Out:
# 正确率：0.6397903825864846
# 召回率：0.5454539812543443
# 准确率：0.8099999999999999
# f-measure：0.5888679533040218

# %%
RFs = at.testOthersByFile(fileName, 'RF')
precisions.append(RFs[0])
recalls.append(RFs[1])
f_measures.append(RFs[2])
# Out:
# 正确率：0.661251535702
# 召回率：0.525452683264843
# 准确率：0.8140000000000001
# f-measure：0.5855821327577534

# %%
bayes = at.testOthersByFile(fileName, 'Bayes')
precisions.append(bayes[0])
recalls.append(bayes[1])
f_measures.append(bayes[2])
# Out:
# 正确率：0.4169770063949086
# 召回率：0.6542875324245561
# 准确率：0.6869999999999999
# f-measure：0.5093473119021644

# %%
trees = at.testOthersByFile(fileName, 'Tree')
precisions.append(trees[0])
recalls.append(trees[1])
f_measures.append(trees[2])
# Out:
# 正确率：0.6577011494252873
# 召回率：0.6508109544552376
# 准确率：0.817
# f-measure：0.6542379111884175

# %%
cp.createClassPlotter(precisions, recalls, f_measures)
