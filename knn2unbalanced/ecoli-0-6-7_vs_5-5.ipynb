# %%
import algorithmTest as at
import createPlotter as cp
import dataTreat as dt
from imp import reload
fileName = 'ecoli-0-6-7_vs_5-5-fold'
file = 'ecoli-0-6-7_vs_5-5-fold'

# %%
dataMat, labels, features, length = dt.createIR(fileName)

# %%
print(length)
cp.createIRPlotter(dataMat, labels, features, file)
# Out:
# 1100

# %%
precisions = []
recalls = []
f_measures = []

# %%
kValues = []
kNNPrecisions = []
kNNRecalls = [] 
kNNF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNs = at.testKNNByDir(fileName, 'KNN', i)
    kNNPrecisions.append(kNNs[0])
    kNNRecalls.append(kNNs[1])
    kNNF_measures.append(kNNs[2])
# Out:
# 正确率：0.8708333333333332
# 召回率：0.675
# 准确率：0.959090909090909
# f-measure：0.7605121293800539
# 正确率：0.9192307692307693
# 召回率：0.725
# 准确率：0.9681818181818184
# f-measure：0.8106432748538013
# 正确率：0.8884615384615385
# 召回率：0.725
# 准确率：0.965909090909091
# f-measure：0.7984505363528009
# 正确率：0.9318181818181819
# 召回率：0.7
# 准确率：0.9670454545454547
# f-measure：0.7994428969359331
# 正确率：0.8
# 召回率：0.4375
# 准确率：0.9488636363636364
# f-measure：0.5656565656565656
# 正确率：0.8
# 召回率：0.4875
# 准确率：0.953409090909091
# f-measure：0.6058252427184466
# 正确率：0.6
# 召回率：0.45
# 准确率：0.95
# f-measure：0.5142857142857143
# 正确率：0.55
# 召回率：0.45
# 准确率：0.9454545454545455
# f-measure：0.49500000000000005

# %%
kValues = []
kNNIPDCPrecisions = []
kNNIPDCRecalls = [] 
kNNIPDCF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIPDCs = at.testKNNByDir(fileName, 'IPDC_KNN', i)
    kNNIPDCPrecisions.append(kNNIPDCs[0])
    kNNIPDCRecalls.append(kNNIPDCs[1])
    kNNIPDCF_measures.append(kNNIPDCs[2])
# Out:
# 正确率：0.8233333333333335
# 召回率：0.8375
# 准确率：0.9625
# f-measure：0.8303562468640241
# 正确率：0.8166666666666668
# 召回率：0.8375
# 准确率：0.9602272727272727
# f-measure：0.8269521410579346
# 正确率：0.791025641025641
# 召回率：0.8375
# 准确率：0.9602272727272727
# f-measure：0.8135996851013579
# 正确率：0.827037037037037
# 召回率：0.8375
# 准确率：0.9636363636363636
# f-measure：0.8322356344217611
# 正确率：0.7986153846153847
# 召回率：0.8125
# 准确率：0.959090909090909
# f-measure：0.8054978634008929
# 正确率：0.802948717948718
# 召回率：0.8125
# 准确率：0.9602272727272727
# f-measure：0.8076961231697155
# 正确率：0.8014574898785425
# 召回率：0.8125
# 准确率：0.9613636363636363
# f-measure：0.806940969151945
# 正确率：0.8325641025641026
# 召回率：0.775
# 准确率：0.9625
# f-measure：0.8027514155833799

# %%
kValues = []
kNNIPDSPrecisions = []
kNNIPDSRecalls = [] 
kNNIPDSF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIPDSs = at.testKNNByDir(fileName, 'IPDS_KNN', i)
    kNNIPDSPrecisions.append(kNNIPDSs[0])
    kNNIPDSRecalls.append(kNNIPDSs[1])
    kNNIPDSF_measures.append(kNNIPDSs[2])
# Out:
# 正确率：0.8911764705882353
# 召回率：0.6875
# 准确率：0.9613636363636363
# f-measure：0.7761993479273405
# 正确率：0.9
# 召回率：0.6875
# 准确率：0.9625
# f-measure：0.7795275590551182
# 正确率：0.9333333333333332
# 召回率：0.725
# 准确率：0.969318181818182
# f-measure：0.8160804020100502
# 正确率：0.9333333333333332
# 召回率：0.675
# 准确率：0.9647727272727273
# f-measure：0.7834196891191709
# 正确率：0.9333333333333332
# 召回率：0.675
# 准确率：0.9647727272727273
# f-measure：0.7834196891191709
# 正确率：0.9318181818181819
# 召回率：0.7125
# 准确率：0.9681818181818184
# f-measure：0.807532826537664
# 正确率：0.9277777777777778
# 召回率：0.675
# 准确率：0.9647727272727273
# f-measure：0.7814558058925477
# 正确率：0.9277777777777778
# 召回率：0.6625
# 准确率：0.9636363636363636
# f-measure：0.7730131004366814

# %%
kValues = []
kNNIPDCSPrecisions = []
kNNIPDCSRecalls = [] 
kNNIPDCSF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIPDCSs = at.testKNNByDir(fileName, 'IPDCS_KNN', i)
    kNNIPDCSPrecisions.append(kNNIPDCSs[0])
    kNNIPDCSRecalls.append(kNNIPDCSs[1])
    kNNIPDCSF_measures.append(kNNIPDCSs[2])
# Out:
# 正确率：0.8538961038961039
# 召回率：0.775
# 准确率：0.9636363636363636
# f-measure：0.8125373729320312
# 正确率：0.8563545150501672
# 召回率：0.825
# 准确率：0.9681818181818184
# f-measure：0.84038490228256
# 正确率：0.8563545150501672
# 召回率：0.825
# 准确率：0.9681818181818184
# f-measure：0.84038490228256
# 正确率：0.8746153846153847
# 召回率：0.825
# 准确率：0.971590909090909
# f-measure：0.8490835030549898
# 正确率：0.8714574898785425
# 召回率：0.8125
# 准确率：0.9704545454545455
# f-measure：0.840946656649136
# 正确率：0.8846153846153847
# 召回率：0.75
# 准确率：0.9670454545454547
# f-measure：0.811764705882353
# 正确率：0.8917582417582418
# 召回率：0.7375
# 准确率：0.9670454545454547
# f-measure：0.8073265323328556
# 正确率：0.9179487179487179
# 召回率：0.7375
# 准确率：0.9693181818181819
# f-measure：0.8178896418199418

# %%
kValues = []
kNNIPNCPrecisions = []
kNNIPNCRecalls = [] 
kNNIPNCF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIPNCs = at.testKNNByDir(fileName, 'IPNC_KNN', i)
    kNNIPNCPrecisions.append(kNNIPNCs[0])
    kNNIPNCRecalls.append(kNNIPNCs[1])
    kNNIPNCF_measures.append(kNNIPNCs[2])
# Out:
# 正确率：0.5642645698427382
# 召回率：0.875
# 准确率：0.9113636363636364
# f-measure：0.6860885885162082
# 正确率：0.6204167925098157
# 召回率：0.875
# 准确率：0.9261363636363636
# f-measure：0.7260379797326979
# 正确率：0.5682857142857143
# 召回率：0.875
# 准确率：0.9113636363636364
# f-measure：0.6890527566069484
# 正确率：0.5554964539007091
# 召回率：0.8625
# 准确率：0.9068181818181819
# f-measure：0.67576430134417
# 正确率：0.5364915966386554
# 召回率：0.8625
# 准确率：0.9011363636363636
# f-measure：0.6615107670591062
# 正确率：0.5572674418604651
# 召回率：0.85
# 准确率：0.9056818181818181
# f-measure：0.6731873579838875
# 正确率：0.605
# 召回率：0.8375
# 准确率：0.9193181818181817
# f-measure：0.7025129982668977
# 正确率：0.6105677655677656
# 召回率：0.825
# 准确率：0.9261363636363636
# f-measure：0.7017689010231942

# %%
cp.createKNNPlotter(kValues, kNNPrecisions, kNNIPDCPrecisions, kNNIPDSPrecisions, kNNIPDCSPrecisions, 'precision')

# %%
cp.createKNNPlotter(kValues, kNNRecalls, kNNIPDCRecalls, kNNIPDSRecalls, kNNIPDCSRecalls, 'recall')

# %%
cp.createKNNPlotter(kValues, kNNF_measures, kNNIPDCF_measures, kNNIPDSF_measures, kNNIPDCSF_measures, 'F-measure')

# %%
precisions.append(kNNIPDCPrecisions[3])
recalls.append(kNNIPDCRecalls[3])
f_measures.append(kNNIPDCF_measures[3])
precisions.append(kNNIPDSPrecisions[3])
recalls.append(kNNIPDSRecalls[3])
f_measures.append(kNNIPDSF_measures[3])
precisions.append(kNNIPDCSPrecisions[3])
recalls.append(kNNIPDCSRecalls[3])
f_measures.append(kNNIPDCSF_measures[3])
precisions.append(kNNPrecisions[3])
recalls.append(kNNRecalls[3])
f_measures.append(kNNF_measures[3])

# %%
SVMs = at.testOthersByDir(fileName, 'SVM', 0)
precisions.append(SVMs[0])
recalls.append(SVMs[1])
f_measures.append(SVMs[2])
# Out:
# 正确率：0.8381818181818181
# 召回率：0.725
# 准确率：0.9556818181818182
# f-measure：0.7774934574004071

# %%
RFs = at.testOthersByDir(fileName, 'RF')
precisions.append(RFs[0])
recalls.append(RFs[1])
f_measures.append(RFs[2])
# Out:
# 正确率：0.8699999999999999
# 召回率：0.6125
# 准确率：0.953409090909091
# f-measure：0.7188870151770658

# %%
bayes = at.testOthersByDir(fileName, 'Bayes')
precisions.append(bayes[0])
recalls.append(bayes[1])
f_measures.append(bayes[2])
# Out:
# 正确率：0.5460784313725491
# 召回率：0.7125
# 准确率：0.896590909090909
# f-measure：0.618286270691334

# %%
trees = at.testOthersByDir(fileName, 'Tree')
precisions.append(trees[0])
recalls.append(trees[1])
f_measures.append(trees[2])
# Out:
# 正确率：0.8620000000000001
# 召回率：0.6875
# 准确率：0.9545454545454545
# f-measure：0.7649241690868023

# %%
cp.createClassPlotter(precisions, recalls, f_measures)
