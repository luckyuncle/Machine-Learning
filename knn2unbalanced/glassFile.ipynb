# %%
import algorithmTest as at
import createPlotter as cp
import dataTreat as dt
from imp import reload
fileName = 'glass1-5-fold'
file = 'glass1-5-fold'

# %%
dataMat, labels, features, length = dt.createIR(fileName)

# %%
print(length)
cp.createIRPlotter(dataMat, labels, features, file)
# Out:
# 1070

# %%
precisions = []
recalls = []
f_measures = []

# %%
kValues = []
kNNPrecisions = []
kNNRecalls = [] 
kNNF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNs = at.testKNNByDir(fileName, 'KNN', i)
    kNNPrecisions.append(kNNs[0])
    kNNRecalls.append(kNNs[1])
    kNNF_measures.append(kNNs[2])
# Out:
# 正确率：0.7149217213047001
# 召回率：0.5342759562841529
# 准确率：0.7587107303141576
# f-measure：0.6115372981730712
# 正确率：0.7642191142191143
# 召回率：0.5795628415300547
# 准确率：0.786672106623147
# f-measure：0.6592036743661791
# 正确率：0.689796001631987
# 召回率：0.5178825136612021
# 准确率：0.7447028423772609
# f-measure：0.591603283017574
# 正确率：0.7322922264098735
# 召回率：0.5307786885245902
# 准确率：0.7645314837481301
# f-measure：0.6154604669536744
# 正确率：0.7180419580419579
# 召回率：0.4811612021857923
# 准确率：0.7458724330205359
# f-measure：0.576205839360352
# 正确率：0.7390165345134919
# 召回率：0.5043306010928962
# 准确率：0.7598803209574323
# f-measure：0.5995246900810305
# 正确率：0.6963576945929887
# 召回率：0.4844398907103825
# 准确率：0.7412212702298382
# f-measure：0.5713823430241702
# 正确率：0.7107637666992506
# 召回率：0.4844398907103825
# 准确率：0.7447300421596628
# f-measure：0.5761734735767712

# %%
kValues = []
kNNIPDCPrecisions = []
kNNIPDCRecalls = [] 
kNNIPDCF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIPDCs = at.testKNNByDir(fileName, 'IPDC_KNN', i)
    kNNIPDCPrecisions.append(kNNIPDCs[0])
    kNNIPDCRecalls.append(kNNIPDCs[1])
    kNNIPDCF_measures.append(kNNIPDCs[2])
# Out:
# 正确率：0.7154406377935789
# 召回率：0.7150819672131148
# 准确率：0.7960016319869442
# f-measure：0.7152612575391551
# 正确率：0.7101858925388337
# 召回率：0.7218579234972677
# 准确率：0.7948048415612675
# f-measure：0.7159743409306581
# 正确率：0.6971428571428572
# 召回率：0.6927459016393442
# 准确率：0.7843601251189991
# f-measure：0.6949374244396422
# 正确率：0.693618881118881
# 召回率：0.6761338797814207
# 准确率：0.7785121719026248
# f-measure：0.6847647817439837
# 正确率：0.692049062049062
# 召回率：0.7093579234972679
# 准确率：0.7866993064055487
# f-measure：0.7005966013819691
# 正确率：0.7104891010628716
# 召回率：0.6521311475409836
# 准确率：0.7796817625458996
# f-measure：0.6800604545048025
# 正确率：0.721060797126371
# 召回率：0.6853551912568305
# 准确率：0.7913232694138447
# f-measure：0.7027547533649032
# 正确率：0.7223575331772054
# 召回率：0.6621857923497267
# 准确率：0.7854753161974705
# f-measure：0.6909641419631216

# %%
kValues = []
kNNIPDSPrecisions = []
kNNIPDSRecalls = [] 
kNNIPDSF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIPDSs = at.testKNNByDir(fileName, 'IPDS_KNN', i)
    kNNIPDSPrecisions.append(kNNIPDSs[0])
    kNNIPDSRecalls.append(kNNIPDSs[1])
    kNNIPDSF_measures.append(kNNIPDSs[2])
# Out:
# 正确率：0.7599011453662616
# 召回率：0.6199590163934425
# 准确率：0.7960560315517475
# f-measure：0.6828337822822933
# 正确率：0.7700159489633174
# 召回率：0.6090710382513661
# 准确率：0.7960560315517475
# f-measure：0.6801520395061055
# 正确率：0.7698245448245449
# 召回率：0.5705601092896175
# 准确率：0.7866993064055487
# f-measure：0.6553807895080728
# 正确率：0.7551233080644846
# 召回率：0.5801775956284152
# 准确率：0.7844145246838025
# f-measure：0.6561901127516736
# 正确率：0.7596757596757596
# 召回率：0.5768989071038251
# 准确率：0.7844145246838026
# f-measure：0.6557899478465679
# 正确率：0.7507203322992796
# 召回率：0.5768989071038251
# 准确率：0.7809329525363797
# f-measure：0.652430646363322
# 正确率：0.7529787193938138
# 召回率：0.573620218579235
# 准确率：0.780905752753978
# f-measure：0.6511746771999405
# 正确率：0.7673297073297073
# 召回率：0.5768989071038251
# 准确率：0.7867265061879505
# f-measure：0.6586255712661662

# %%
kValues = []
kNNIPDCSPrecisions = []
kNNIPDCSRecalls = [] 
kNNIPDCSF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIPDCSs = at.testKNNByDir(fileName, 'IPDCS_KNN', i)
    kNNIPDCSPrecisions.append(kNNIPDCSs[0])
    kNNIPDCSRecalls.append(kNNIPDCSs[1])
    kNNIPDCSF_measures.append(kNNIPDCSs[2])
# Out:
# 正确率：0.7353654569115096
# 召回率：0.6886338797814208
# 准确率：0.8006799945600435
# f-measure：0.7112328701307662
# 正确率：0.7295743337122648
# 召回率：0.698688524590164
# 准确率：0.8006527947776417
# f-measure：0.7137974803967599
# 正确率：0.7366454383584529
# 召回率：0.698688524590164
# 准确率：0.8041615667074662
# f-measure：0.7171651026990534
# 正确率：0.7229620661824052
# 召回率：0.6763524590163935
# 准确率：0.7936624507003944
# f-measure：0.6988810055674568
# 正确率：0.7119795657726693
# 召回率：0.6297950819672131
# 准确率：0.7785665714674282
# f-measure：0.6683703999625823
# 正确率：0.7105744537947928
# 召回率：0.6431284153005464
# 准确率：0.7808785529715763
# f-measure：0.6751712400927345
# 正确率：0.7258490566037736
# 召回率：0.6431284153005464
# 准确率：0.7866993064055487
# f-measure：0.6819895332121402
# 正确率：0.7198245614035088
# 召回率：0.6464071038251367
# 准确率：0.784360125118999
# f-measure：0.6811432084926405

# %%
kValues = []
kNNIPNCPrecisions = []
kNNIPNCRecalls = [] 
kNNIPNCF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIPNCs = at.testKNNByDir(fileName, 'IPNC_KNN', i)
    kNNIPNCPrecisions.append(kNNIPNCs[0])
    kNNIPNCRecalls.append(kNNIPNCs[1])
    kNNIPNCF_measures.append(kNNIPNCs[2])
# Out:
# 正确率：0.4
# 召回率：0.10491803278688525
# 准确率：0.6807833537331701
# f-measure：0.1662337662337662
# 正确率：0.4
# 召回率：0.10491803278688525
# 准确率：0.6807833537331701
# f-measure：0.1662337662337662
# 正确率：0.4
# 召回率：0.10491803278688525
# 准确率：0.6807833537331701
# f-measure：0.1662337662337662
# 正确率：0.4
# 召回率：0.10163934426229508
# 准确率：0.6796137630898953
# f-measure：0.1620915032679739
# 正确率：0.4
# 召回率：0.10163934426229508
# 准确率：0.6796137630898953
# f-measure：0.1620915032679739
# 正确率：0.4
# 召回率：0.10163934426229508
# 准确率：0.6796137630898953
# f-measure：0.1620915032679739
# 正确率：0.4
# 召回率：0.10163934426229508
# 准确率：0.6796137630898953
# f-measure：0.1620915032679739
# 正确率：0.4
# 召回率：0.10163934426229508
# 准确率：0.6796137630898953
# f-measure：0.1620915032679739

# %%
cp.createKNNPlotter(kValues, kNNPrecisions, kNNIPDCPrecisions, kNNIPDSPrecisions, kNNIPDCSPrecisions, 'precision')

# %%
cp.createKNNPlotter(kValues, kNNRecalls, kNNIPDCRecalls, kNNIPDSRecalls, kNNIPDCSRecalls, 'recall')

# %%
cp.createKNNPlotter(kValues, kNNF_measures, kNNIPDCF_measures, kNNIPDSF_measures, kNNIPDCSF_measures, 'F-measure')

# %%
precisions.append(kNNIPDCPrecisions[3])
recalls.append(kNNIPDCRecalls[3])
f_measures.append(kNNIPDCF_measures[3])
precisions.append(kNNIPDSPrecisions[3])
recalls.append(kNNIPDSRecalls[3])
f_measures.append(kNNIPDSF_measures[3])
precisions.append(kNNIPDCSPrecisions[3])
recalls.append(kNNIPDCSRecalls[3])
f_measures.append(kNNIPDCSF_measures[3])
precisions.append(kNNPrecisions[3])
recalls.append(kNNRecalls[3])
f_measures.append(kNNF_measures[3])

# %%
SVMs = at.testOthersByDir(fileName, 'SVM')
precisions.append(SVMs[0])
recalls.append(SVMs[1])
f_measures.append(SVMs[2])
# Out:
# 正确率：0.8786324786324787
# 召回率：0.28644808743169403
# 准确率：0.7131510947912416
# f-measure：0.43204324300055247

# %%
RFs = at.testOthersByDir(fileName, 'RF')
precisions.append(RFs[0])
recalls.append(RFs[1])
f_measures.append(RFs[2])
# Out:
# 正确率：0.831183932346723
# 召回率：0.5635655737704918
# 准确率：0.803046375628995
# f-measure：0.6717000403116515

# %%
bayes = at.testOthersByDir(fileName, 'Bayes')
precisions.append(bayes[0])
recalls.append(bayes[1])
f_measures.append(bayes[2])
# Out:
# 正确率：0.45491109042328615
# 召回率：0.8720901639344263
# 准确率：0.5791921664626682
# f-measure：0.5979248114800798

# %%
trees = at.testOthersByDir(fileName, 'Tree')
precisions.append(trees[0])
recalls.append(trees[1])
f_measures.append(trees[2])
# Out:
# 正确率：0.7452741461437113
# 召回率：0.6377459016393442
# 准确率：0.7831633346933226
# f-measure：0.6873299241942296

# %%
cp.createClassPlotter(precisions, recalls, f_measures)
