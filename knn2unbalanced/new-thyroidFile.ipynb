# %%
import algorithmTest as at
import createPlotter as cp
import dataTreat as dt
from imp import reload
fileName = 'new-thyroid1-5-fold'
file = 'new-thyroid1-5-fold'

# %%
dataMat, labels, features, length = dt.createIR(fileName)

# %%
print(length)
cp.createIRPlotter(dataMat, labels, features, file)
# Out:
# 1075

# %%
precisions = []
recalls = []
f_measures = []

# %%
kValues = []
kNNPrecisions = []
kNNRecalls = [] 
kNNF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNs = at.testKNNByDir(fileName, 'KNN', i)
    kNNPrecisions.append(kNNs[0])
    kNNRecalls.append(kNNs[1])
    kNNF_measures.append(kNNs[2])
# Out:
# 正确率：0.9060344827586206
# 召回率：0.8428571428571429
# 准确率：0.9581395348837208
# f-measure：0.8733046968523343
# 正确率：0.9310344827586207
# 召回率：0.8428571428571429
# 准确率：0.9627906976744185
# f-measure：0.8847542349347404
# 正确率：0.9259740259740259
# 召回率：0.7428571428571428
# 准确率：0.9476744186046512
# f-measure：0.8243690939410784
# 正确率：0.9619047619047618
# 召回率：0.7428571428571428
# 准确率：0.9534883720930232
# f-measure：0.8383080606544293
# 正确率：0.9285714285714285
# 召回率：0.6857142857142857
# 准确率：0.9395348837209303
# f-measure：0.788874841972187
# 正确率：0.9366666666666668
# 召回率：0.7142857142857142
# 准确率：0.9453488372093023
# f-measure：0.8104989904816844
# 正确率：0.9666666666666666
# 召回率：0.6142857142857143
# 准确率：0.9325581395348838
# f-measure：0.7512048192771085
# 正确率：1.0
# 召回率：0.65
# 准确率：0.9430232558139535
# f-measure：0.787878787878788

# %%
kValues = []
kNNIPDCPrecisions = []
kNNIPDCRecalls = [] 
kNNIPDCF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIPDCs = at.testKNNByDir(fileName, 'IPDC_KNN', i)
    kNNIPDCPrecisions.append(kNNIPDCs[0])
    kNNIPDCRecalls.append(kNNIPDCs[1])
    kNNIPDCF_measures.append(kNNIPDCs[2])
# Out:
# 正确率：0.9102941176470589
# 召回率：0.8571428571428571
# 准确率：0.9593023255813954
# f-measure：0.8829192915725663
# 正确率：0.90625
# 召回率：0.8642857142857142
# 准确率：0.9604651162790697
# f-measure：0.8847705496722138
# 正确率：0.8868055555555555
# 召回率：0.8642857142857142
# 准确率：0.9558139534883721
# f-measure：0.8754008271486035
# 正确率：0.9069124423963133
# 召回率：0.8071428571428572
# 准确率：0.9523255813953488
# f-measure：0.8541240182052119
# 正确率：0.8879310344827587
# 召回率：0.7714285714285715
# 准确率：0.9430232558139535
# f-measure：0.8255900252337837
# 正确率：0.8879310344827587
# 召回率：0.7714285714285715
# 准确率：0.9430232558139535
# f-measure：0.8255900252337837
# 正确率：0.8879310344827587
# 召回率：0.7714285714285715
# 准确率：0.9430232558139535
# f-measure：0.8255900252337837
# 正确率：0.8928571428571429
# 召回率：0.7714285714285715
# 准确率：0.9441860465116279
# f-measure：0.8277130594727161

# %%
kValues = []
kNNIPDSPrecisions = []
kNNIPDSRecalls = [] 
kNNIPDSF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIPDSs = at.testKNNByDir(fileName, 'IPDS_KNN', i)
    kNNIPDSPrecisions.append(kNNIPDSs[0])
    kNNIPDSRecalls.append(kNNIPDSs[1])
    kNNIPDSF_measures.append(kNNIPDSs[2])
# Out:
# 正确率：0.9375
# 召回率：0.8785714285714284
# 准确率：0.9686046511627907
# f-measure：0.907079646017699
# 正确率：0.9375
# 召回率：0.8785714285714284
# 准确率：0.9686046511627907
# f-measure：0.907079646017699
# 正确率：0.9375
# 召回率：0.8785714285714284
# 准确率：0.9686046511627907
# f-measure：0.907079646017699
# 正确率：0.9400000000000001
# 召回率：0.8714285714285716
# 准确率：0.9686046511627907
# f-measure：0.904416403785489
# 正确率：0.9448275862068964
# 召回率：0.8714285714285716
# 准确率：0.969767441860465
# f-measure：0.9066449688093301
# 正确率：0.9615384615384615
# 召回率：0.8714285714285716
# 准确率：0.9732558139534884
# f-measure：0.9142685851318945
# 正确率：0.9615384615384615
# 召回率：0.8714285714285716
# 准确率：0.9732558139534884
# f-measure：0.9142685851318945
# 正确率：0.96
# 召回率：0.8642857142857142
# 准确率：0.9720930232558139
# f-measure：0.9096319498825371

# %%
kValues = []
kNNIPDCSPrecisions = []
kNNIPDCSRecalls = [] 
kNNIPDCSF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIPDCSs = at.testKNNByDir(fileName, 'IPDCS_KNN', i)
    kNNIPDCSPrecisions.append(kNNIPDCSs[0])
    kNNIPDCSRecalls.append(kNNIPDCSs[1])
    kNNIPDCSF_measures.append(kNNIPDCSs[2])
# Out:
# 正确率：0.9102941176470589
# 召回率：0.8857142857142858
# 准确率：0.963953488372093
# f-measure：0.8978360042110188
# 正确率：0.9102941176470589
# 召回率：0.8857142857142858
# 准确率：0.963953488372093
# f-measure：0.8978360042110188
# 正确率：0.8908496732026144
# 召回率：0.8857142857142858
# 准确率：0.9593023255813954
# f-measure：0.8882745572081779
# 正确率：0.90625
# 召回率：0.8714285714285716
# 准确率：0.961627906976744
# f-measure：0.8884982420894024
# 正确率：0.90625
# 召回率：0.8714285714285716
# 准确率：0.961627906976744
# f-measure：0.8884982420894024
# 正确率：0.90625
# 召回率：0.8714285714285716
# 准确率：0.961627906976744
# f-measure：0.8884982420894024
# 正确率：0.915
# 召回率：0.8714285714285716
# 准确率：0.963953488372093
# f-measure：0.8926829268292684
# 正确率：0.9114285714285714
# 召回率：0.8142857142857143
# 准确率：0.9546511627906977
# f-measure：0.8601229895931883

# %%
kValues = []
kNNIPNCPrecisions = []
kNNIPNCRecalls = [] 
kNNIPNCF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIPNCs = at.testKNNByDir(fileName, 'IPNC_KNN', i)
    kNNIPNCPrecisions.append(kNNIPNCs[0])
    kNNIPNCRecalls.append(kNNIPNCs[1])
    kNNIPNCF_measures.append(kNNIPNCs[2])
# Out:
# 正确率：0.95
# 召回率：0.8357142857142857
# 准确率：0.9651162790697674
# f-measure：0.8892000000000001
# 正确率：0.9481481481481481
# 召回率：0.8571428571428571
# 准确率：0.9686046511627907
# f-measure：0.9003516998827666
# 正确率：0.9538461538461538
# 召回率：0.8571428571428571
# 准确率：0.969767441860465
# f-measure：0.9029126213592232
# 正确率：0.9739130434782609
# 召回率：0.8
# 准确率：0.963953488372093
# f-measure：0.8784313725490197
# 正确率：0.9727272727272727
# 召回率：0.7642857142857143
# 准确率：0.9581395348837208
# f-measure：0.8560000000000001
# 正确率：0.9727272727272727
# 召回率：0.7642857142857143
# 准确率：0.9581395348837208
# f-measure：0.8560000000000001
# 正确率：0.99
# 召回率：0.7642857142857143
# 准确率：0.9604651162790697
# f-measure：0.8626221498371335
# 正确率：0.99
# 召回率：0.7357142857142858
# 准确率：0.9558139534883721
# f-measure：0.8441225165562914

# %%
cp.createKNNPlotter(kValues, kNNPrecisions, kNNIPDCPrecisions, kNNIPDSPrecisions, kNNIPDCSPrecisions, 'precision')

# %%
cp.createKNNPlotter(kValues, kNNRecalls, kNNIPDCRecalls, kNNIPDSRecalls, kNNIPDCSRecalls, 'recall')

# %%
cp.createKNNPlotter(kValues, kNNF_measures, kNNIPDCF_measures, kNNIPDSF_measures, kNNIPDCSF_measures, 'F-measure')

# %%
precisions.append(kNNIPDCPrecisions[3])
recalls.append(kNNIPDCRecalls[3])
f_measures.append(kNNIPDCF_measures[3])
precisions.append(kNNIPDSPrecisions[3])
recalls.append(kNNIPDSRecalls[3])
f_measures.append(kNNIPDSF_measures[3])
precisions.append(kNNIPDCSPrecisions[3])
recalls.append(kNNIPDCSRecalls[3])
f_measures.append(kNNIPDCSF_measures[3])
precisions.append(kNNPrecisions[3])
recalls.append(kNNRecalls[3])
f_measures.append(kNNF_measures[3])

# %%
SVMs = at.testOthersByDir(fileName, 'SVM')
precisions.append(SVMs[0])
recalls.append(SVMs[1])
f_measures.append(SVMs[2])
# Out:
# 正确率：1.0
# 召回率：0.33571428571428574
# 准确率：0.8918604651162789
# f-measure：0.5026737967914439

# %%
RFs = at.testOthersByDir(fileName, 'RF')
precisions.append(RFs[0])
recalls.append(RFs[1])
f_measures.append(RFs[2])
# Out:
# 正确率：0.9264285714285714
# 召回率：0.8785714285714284
# 准确率：0.9674418604651163
# f-measure：0.9018655661710667

# %%
bayes = at.testOthersByDir(fileName, 'Bayes')
precisions.append(bayes[0])
recalls.append(bayes[1])
f_measures.append(bayes[2])
# Out:
# 正确率：0.9078571428571429
# 召回率：0.9928571428571429
# 准确率：0.9790697674418605
# f-measure：0.9484565415794277

# %%
trees = at.testOthersByDir(fileName, 'Tree')
precisions.append(trees[0])
recalls.append(trees[1])
f_measures.append(trees[2])
# Out:
# 正确率：0.8942727272727273
# 召回率：0.9214285714285715
# 准确率：0.9627906976744185
# f-measure：0.9076475763362875

# %%
cp.createClassPlotter(precisions, recalls, f_measures)
