# %%
import kNN
from imp import reload
import createPlotter as cp
fileName = 'pima.dat'
file = 'pima'

# %%
dataMat, labels, features = kNN.file2matrix(fileName)

# %%
cp.createIRPlotter(dataMat, labels, features, file)

# %%
precisions = []
recalls = []
f_measures = []

# %%
kValues = []
kNNPrecisions = []
kNNRecalls = [] 
kNNF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNPrecision, kNNRecall, kNNF_measure = kNN.testKNN(fileName, i)
    kNNPrecisions.append(kNNPrecision)
    kNNRecalls.append(kNNRecall)
    kNNF_measures.append(kNNF_measure)
# Out:
# 正确率：0.6272774921035886
# 召回率：0.6802689055172075
# 准确率：0.7711111111111111
# f-measure：0.6526993975668313
# 正确率：0.6419263775339717
# 召回率：0.7047662432017271
# 准确率：0.7866666666666666
# f-measure：0.6718801819223753
# 正确率：0.5840037539830683
# 召回率：0.6465884654348811
# 准确率：0.7511111111111111
# f-measure：0.6137046620930621
# 正确率：0.610516908103122
# 召回率：0.68172755679866
# 准确率：0.7722222222222223
# f-measure：0.6441601592420787
# 正确率：0.5686593683697565
# 召回率：0.6622363016352787
# 准确率：0.7566666666666666
# f-measure：0.6118908144309266
# 正确率：0.5625372922157976
# 召回率：0.6742468284403769
# 准确率：0.7611111111111111
# f-measure：0.6133471134068372
# 正确率：0.545942184167042
# 召回率：0.6566619730329408
# 准确率：0.7477777777777778
# f-measure：0.5962052761429587
# 正确率：0.5439031256029766
# 召回率：0.6622377595398841
# 准确率：0.7511111111111111
# f-measure：0.5972655296622209

# %%
kValues = []
kNNIPPrecisions = []
kNNIPRecalls = [] 
kNNIPF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIPPrecision, kNNIPRecall, kNNIPF_measure = kNN.testIPKNN(fileName, i)
    kNNIPPrecisions.append(kNNIPPrecision)
    kNNIPRecalls.append(kNNIPRecall)
    kNNIPF_measures.append(kNNIPF_measure)
# Out:
# 正确率：0.6967091445575124
# 召回率：0.7518565803080588
# 准确率：0.8255555555555555
# f-measure：0.7232331207408292
# 正确率：0.6872951949314736
# 召回率：0.7460357398197689
# 准确率：0.8188888888888888
# f-measure：0.71546181944962
# 正确率：0.6699396893021333
# 召回率：0.7350244577154593
# 准确率：0.8133333333333332
# f-measure：0.7009745520932469
# 正确率：0.6728010414965505
# 召回率：0.7377360169465433
# 准确率：0.8166666666666667
# f-measure：0.703773867662869
# 正确率：0.6899096321741565
# 召回率：0.7440615754321407
# 准确率：0.821111111111111
# f-measure：0.7159631171091825
# 正确率：0.6883708328401766
# 召回率：0.7470060093415356
# 准确率：0.8222222222222222
# f-measure：0.716490796947039
# 正确率：0.6864694844872153
# 召回率：0.7453302724986492
# 准确率：0.82
# f-measure：0.7146900052727341
# 正确率：0.6888487300922674
# 召回率：0.747615844862237
# 准确率：0.8222222222222222
# f-measure：0.7170301785500285

# %%
kValues = []
kNNIP2Precisions = []
kNNIP2Recalls = [] 
kNNIP2F_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIP2Precision, kNNIP2Recall, kNNIP2F_measure = kNN.testIP2KNN(fileName, i)
    kNNIP2Precisions.append(kNNIP2Precision)
    kNNIP2Recalls.append(kNNIP2Recall)
    kNNIP2F_measures.append(kNNIP2F_measure)
# Out:
# 正确率：0.693614420528073
# 召回率：0.7322954204204204
# 准确率：0.8122222222222222
# f-measure：0.7124302660712458
# 正确率：0.6891296813308514
# 召回率：0.7390243886230728
# 准确率：0.8111111111111111
# f-measure：0.7132054617104109
# 正确率：0.6704779915795661
# 召回率：0.7333360645202751
# 准确率：0.8099999999999999
# f-measure：0.7004997414806449
# 正确率：0.6745865862369412
# 召回率：0.7365252857899918
# 准确率：0.8111111111111111
# f-measure：0.704196581529115
# 正确率：0.6637717843169153
# 召回率：0.7343366822508902
# 准确率：0.8088888888888889
# f-measure：0.6972734684364313
# 正确率：0.6658774198527835
# 召回率：0.7486066535635502
# 准确率：0.8122222222222222
# f-measure：0.7048227354806031
# 正确率：0.6494347962085204
# 召回率：0.7286955156389973
# 准确率：0.8011111111111111
# f-measure：0.6867858861077518
# 正确率：0.6638660131397373
# 召回率：0.7254404180380412
# 准确率：0.8022222222222222
# f-measure：0.6932887191561742

# %%
kValues = []
kNNIP3Precisions = []
kNNIP3Recalls = [] 
kNNIP3F_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIP3Precision, kNNIP3Recall, kNNIP3F_measure = kNN.testIP3KNN(fileName, i)
    kNNIP3Precisions.append(kNNIP3Precision)
    kNNIP3Recalls.append(kNNIP3Recall)
    kNNIP3F_measures.append(kNNIP3F_measure)
# Out:
# 正确率：0.6844925983574703
# 召回率：0.7450866220250159
# 准确率：0.8177777777777777
# f-measure：0.7135054436155563
# 正确率：0.6860344432356132
# 召回率：0.7418287457301395
# 准确率：0.8155555555555555
# f-measure：0.7128415025836989
# 正确率：0.6811599477829027
# 召回率：0.741213878170748
# 准确率：0.8177777777777777
# f-measure：0.7099191469053392
# 正确率：0.6884162479206549
# 召回率：0.7363277881685589
# 准确率：0.8188888888888888
# f-measure：0.7115664292403092
# 正确率：0.6778468526387771
# 召回率：0.7250019658003166
# 准确率：0.8099999999999999
# f-measure：0.700631877384309
# 正确率：0.6833916416137986
# 召回率：0.7372059587608886
# 准确率：0.8155555555555555
# f-measure：0.7092795176230046
# 正确率：0.6625431198732875
# 召回率：0.7207078288101427
# 准确率：0.8055555555555556
# f-measure：0.6904025822233583
# 正确率：0.6765685637773968
# 召回率：0.7347995448426483
# 准确率：0.8133333333333332
# f-measure：0.7044827918133316

# %%
reload(kNN)
kValues = []
kNNIP4Precisions = []
kNNIP4Recalls = [] 
kNNIP4F_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNPrecision, kNNRecall, kNNF_measure = kNN.testIP4KNN(fileName, i)
    kNNIP4Precisions.append(kNNPrecision)
    kNNIP4Recalls.append(kNNRecall)
    kNNIP4F_measures.append(kNNF_measure)
# Out:
# 正确率：0.3156525686278578
# 召回率：0.840909090909091
# 准确率：0.7566666666666667
# f-measure：0.4590072865362722
# 正确率：0.3119488649241541
# 召回率：0.7909090909090909
# 准确率：0.7555555555555556
# f-measure：0.44742515001558497
# 正确率：0.3156525686278578
# 召回率：0.890909090909091
# 准确率：0.7577777777777779
# f-measure：0.46614732158369643
# 正确率：0.3156525686278578
# 召回率：0.890909090909091
# 准确率：0.7577777777777779
# f-measure：0.46614732158369643
# 正确率：0.3188783750794707
# 召回率：0.990909090909091
# 准确率：0.758888888888889
# f-measure：0.48248969999431324
# 正确率：0.3188783750794707
# 召回率：1.0
# 准确率：0.76
# f-measure：0.48355994169705946
# 正确率：0.315174671375767
# 召回率：0.9
# 准确率：0.758888888888889
# f-measure：0.4668583223793599
# 正确率：0.315174671375767
# 召回率：0.9
# 准确率：0.758888888888889
# f-measure：0.4668583223793599

# %%
cp.createKNNPlotter(kValues, kNNPrecisions, kNNIPPrecisions, kNNIP2Precisions, kNNIP3Precisions, 'precision')

# %%
cp.createKNNPlotter(kValues, kNNRecalls, kNNIPRecalls, kNNIP2Recalls, kNNIP3Recalls, 'recall')

# %%
cp.createKNNPlotter(kValues, kNNF_measures, kNNIPF_measures, kNNIP2F_measures, kNNIP3F_measures, 'F-measure')

# %%
precisions.append(kNNIPPrecisions[3])
recalls.append(kNNIPRecalls[3])
f_measures.append(kNNIPF_measures[3])
precisions.append(kNNIP2Precisions[3])
recalls.append(kNNIP2Recalls[3])
f_measures.append(kNNIP2F_measures[3])
precisions.append(kNNIP3Precisions[3])
recalls.append(kNNIP3Recalls[3])
f_measures.append(kNNIP3F_measures[3])
precisions.append(kNNPrecisions[3])
recalls.append(kNNRecalls[3])
f_measures.append(kNNF_measures[3])

# %%
SVMs = kNN.testSVM(fileName)
precisions.append(SVMs[0])
recalls.append(SVMs[1])
f_measures.append(SVMs[2])
# Out:
# 正确率：0.30962328352880525
# 召回率：0.8
# 准确率：0.7566666666666667
# f-measure：0.44645535200976894

# %%
RFs = kNN.testRandomForest(fileName)
precisions.append(RFs[0])
recalls.append(RFs[1])
f_measures.append(RFs[2])
# Out:
# 正确率：0.6361690960432209
# 召回率：0.7681288471501453
# 准确率：0.8133333333333332
# f-measure：0.6959489426083177

# %%
bayes = kNN.testBayes(fileName)
precisions.append(bayes[0])
recalls.append(bayes[1])
f_measures.append(bayes[2])
# Out:
# 正确率：0.47150339615109643
# 召回率：0.44716555714400547
# 准确率：0.6033333333333333
# f-measure：0.4590120915242644

# %%
trees = kNN.testDecisionTree(fileName)
precisions.append(trees[0])
recalls.append(trees[1])
f_measures.append(trees[2])
# Out:
# 正确率：0.6912841694386465
# 召回率：0.6851467507149673
# 准确率：0.7844444444444444
# f-measure：0.6882017768951673

# %%
reload(cp)
cp.createClassPlotter(precisions, recalls, f_measures)
