# %%
import algorithmTest as at
import createPlotter as cp
import dataTreat as dt
from imp import reload
fileName = 'pima-5-fold'
file = 'pima-5-fold'

# %%
dataMat, labels, features, length = dt.createIR(fileName)

# %%
print(length)
cp.createIRPlotter(dataMat, labels, features, file)
# Out:
# 3840

# %%
precisions = []
recalls = []
f_measures = []

# %%
kValues = []
kNNPrecisions = []
kNNRecalls = [] 
kNNF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNs = at.testKNNByDir(fileName, 'KNN', i)
    kNNPrecisions.append(kNNs[0])
    kNNRecalls.append(kNNs[1])
    kNNF_measures.append(kNNs[2])
# Out:
# 正确率：0.5994069339470117
# 召回率：0.5744894427137417
# 准确率：0.7165489233893142
# f-measure：0.5866837351036251
# 正确率：0.6220272844412135
# 召回率：0.5791623399100034
# 准确率：0.729552857565887
# f-measure：0.5998299856101709
# 正确率：0.6255024421490912
# 召回率：0.5399446175147109
# 准确率：0.7256229112906638
# f-measure：0.5795830433999051
# 正确率：0.6457219722031617
# 召回率：0.5493596400138456
# 准确率：0.737010871864292
# f-measure：0.5936558416968523
# 正确率：0.641589549486852
# 召回率：0.5435444790584978
# 准确率：0.7330851558864587
# f-measure：0.5885114241015362
# 正确率：0.6624318122678778
# 召回率：0.5391138802353754
# 准确率：0.7431828757561657
# f-measure：0.5944446173479506
# 正确率：0.6468528606546806
# 召回率：0.5026306680512288
# 准确率：0.7304792926942765
# f-measure：0.5656942050274358
# 正确率：0.6866684357953708
# 召回率：0.5361716857043959
# 准确率：0.752265324252295
# f-measure：0.6021591314633274

# %%
kValues = []
kNNIPDCPrecisions = []
kNNIPDCRecalls = [] 
kNNIPDCF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIPDCs = at.testKNNByDir(fileName, 'IPDC_KNN', i)
    kNNIPDCPrecisions.append(kNNIPDCs[0])
    kNNIPDCRecalls.append(kNNIPDCs[1])
    kNNIPDCF_measures.append(kNNIPDCs[2])
# Out:
# 正确率：0.6618246765278079
# 召回率：0.6294219453097958
# 准确率：0.75882228520665
# f-measure：0.6452167514852163
# 正确率：0.6584549666188597
# 召回率：0.6247490481135342
# 准确率：0.7558906891154449
# f-measure：0.6411593307032328
# 正确率：0.6858665418809068
# 召回率：0.6321218414676358
# 准确率：0.7705021363001819
# f-measure：0.6578983956646078
# 正确率：0.6788101492003931
# 召回率：0.6164070612668743
# 准确率：0.7649858285037439
# f-measure：0.6461053263425844
# 正确率：0.7047108980386778
# 召回率：0.6255797853928695
# 准确率：0.7779728414907567
# f-measure：0.6627918211407023
# 正确率：0.6889386523840306
# 召回率：0.6201453790238838
# 准确率：0.7705148271923516
# f-measure：0.6527344486012885
# 正确率：0.6876756571847239
# 召回率：0.621079958463136
# 准确率：0.7695418587926731
# f-measure：0.652683455175051
# 正确率：0.6965674331427045
# 召回率：0.6285219799238491
# 准确率：0.7750666271838911
# f-measure：0.6607975852982485

# %%
kValues = []
kNNIPDSPrecisions = []
kNNIPDSRecalls = [] 
kNNIPDSF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIPDSs = at.testKNNByDir(fileName, 'IPDS_KNN', i)
    kNNIPDSPrecisions.append(kNNIPDSs[0])
    kNNIPDSRecalls.append(kNNIPDSs[1])
    kNNIPDSF_measures.append(kNNIPDSs[2])
# Out:
# 正确率：0.6063558124364349
# 召回率：0.5876427829698858
# 准确率：0.7224332670586742
# f-measure：0.5968526570483207
# 正确率：0.6242560167879861
# 召回率：0.5959501557632398
# 准确率：0.7331486103473075
# f-measure：0.6097747721814969
# 正确率：0.6421809693002416
# 召回率：0.5838352371062652
# 准确率：0.7406193155378823
# f-measure：0.6116197755255838
# 正确率：0.6519715117247223
# 召回率：0.6005538248528903
# 准确率：0.74841998392487
# f-measure：0.6252072890297832
# 正确率：0.6732591026544515
# 召回率：0.5893388715818622
# 准确率：0.7562121917170777
# f-measure：0.6285100529811697
# 正确率：0.6876078732003201
# 召回率：0.5922118380062306
# 准确率：0.7636913575024324
# f-measure：0.6363545097014012
# 正确率：0.6906348814229248
# 召回率：0.581031498788508
# 准确率：0.762714158805364
# f-measure：0.631109898811773
# 正确率：0.6846314851037217
# 召回率：0.5931118033921772
# 准确率：0.7623841956089513
# f-measure：0.6355940484209966

# %%
kValues = []
kNNIPDCSPrecisions = []
kNNIPDCSRecalls = [] 
kNNIPDCSF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIPDCSs = at.testKNNByDir(fileName, 'IPDCS_KNN', i)
    kNNIPDCSPrecisions.append(kNNIPDCSs[0])
    kNNIPDCSRecalls.append(kNNIPDCSs[1])
    kNNIPDCSF_measures.append(kNNIPDCSs[2])
# Out:
# 正确率：0.6394181382527248
# 召回率：0.6191761855313257
# 准确率：0.7448496129277888
# f-measure：0.6291343863883413
# 正确率：0.6532794254683483
# 召回率：0.6117341640706127
# 准确率：0.7510173865222725
# f-measure：0.6318245852031646
# 正确率：0.6719977120304896
# 召回率：0.616337833160263
# 准确率：0.7607597614112271
# f-measure：0.642965437486556
# 正确率：0.6826478433687103
# 召回率：0.6117341640706127
# 准确率：0.7656330640043996
# f-measure：0.6452484744343766
# 正确率：0.7011287342330859
# 召回率：0.607061266874351
# 准确率：0.7724523033969288
# f-measure：0.6507129656781285
# 正确率：0.6916715418933949
# 召回率：0.6107995846313603
# 准确率：0.7692076652988705
# f-measure：0.6487248460041597
# 正确率：0.6904576362596156
# 召回率：0.609865005192108
# 准确率：0.7685604297982149
# f-measure：0.6476637974284392
# 正确率：0.7001020535804475
# 召回率：0.6164070612668744
# 准确率：0.7740851981894327
# f-measure：0.6555941688022038

# %%
kValues = []
kNNIPNCPrecisions = []
kNNIPNCRecalls = [] 
kNNIPNCF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIPNCs = at.testKNNByDir(fileName, 'IPNC_KNN', i)
    kNNIPNCPrecisions.append(kNNIPNCs[0])
    kNNIPNCRecalls.append(kNNIPNCs[1])
    kNNIPNCF_measures.append(kNNIPNCs[2])
# Out:
# 正确率：0.4
# 召回率：0.105607476635514
# 准确率：0.6870045264182072
# f-measure：0.16709796672828095
# 正确率：0.6
# 召回率：0.10837660089996537
# 准确率：0.6879774948178857
# f-measure：0.18359149767896407
# 正确率：0.4
# 召回率：0.10280373831775699
# 准确率：0.6860273277211388
# f-measure：0.16356877323420072
# 正确率：0.4
# 召回率：0.10093457943925233
# 准确率：0.6853758619230932
# f-measure：0.16119402985074627
# 正确率：0.6
# 召回率：0.10463828314295602
# 准确率：0.6866745632217944
# f-measure：0.17819914525715969
# 正确率：0.6
# 召回率：0.10463828314295602
# 准确率：0.6866745632217944
# f-measure：0.17819914525715969
# 正确率：0.6
# 召回率：0.10463828314295602
# 准确率：0.6866745632217944
# f-measure：0.17819914525715969
# 正确率：0.4
# 召回率：0.10093457943925233
# 准确率：0.6853758619230932
# f-measure：0.16119402985074627

# %%
cp.createKNNPlotter(kValues, kNNPrecisions, kNNIPDCPrecisions, kNNIPDSPrecisions, kNNIPDCSPrecisions, 'precision')

# %%
cp.createKNNPlotter(kValues, kNNRecalls, kNNIPDCRecalls, kNNIPDSRecalls, kNNIPDCSRecalls, 'recall')

# %%
cp.createKNNPlotter(kValues, kNNF_measures, kNNIPDCF_measures, kNNIPDSF_measures, kNNIPDCSF_measures, 'F-measure')

# %%
precisions.append(kNNIPDCPrecisions[3])
recalls.append(kNNIPDCRecalls[3])
f_measures.append(kNNIPDCF_measures[3])
precisions.append(kNNIPDSPrecisions[3])
recalls.append(kNNIPDSRecalls[3])
f_measures.append(kNNIPDSF_measures[3])
precisions.append(kNNIPDCSPrecisions[3])
recalls.append(kNNIPDCSRecalls[3])
f_measures.append(kNNIPDCSF_measures[3])
precisions.append(kNNPrecisions[3])
recalls.append(kNNRecalls[3])
f_measures.append(kNNF_measures[3])

# %%
SVMs = at.testOthersByDir(fileName, 'SVM', 0)
precisions.append(SVMs[0])
recalls.append(SVMs[1])
f_measures.append(SVMs[2])
# Out:
# 正确率：0.7196487596300928
# 召回率：0.5863966770508827
# 准确率：0.7753458268116249
# f-measure：0.6462250537979662

# %%
RFs = at.testOthersByDir(fileName, 'RF')
precisions.append(RFs[0])
recalls.append(RFs[1])
f_measures.append(RFs[2])
# Out:
# 正确率：0.6911002830072597
# 召回率：0.5064728279681551
# 准确率：0.7467743982401963
# f-measure：0.584554732460864

# %%
bayes = at.testOthersByDir(fileName, 'Bayes')
precisions.append(bayes[0])
recalls.append(bayes[1])
f_measures.append(bayes[2])
# Out:
# 正确率：0.6811904572880279
# 召回率：0.6106611284181378
# 准确率：0.7636617454207031
# f-measure：0.6440004996205332

# %%
trees = at.testOthersByDir(fileName, 'Tree')
precisions.append(trees[0])
recalls.append(trees[1])
f_measures.append(trees[2])
# Out:
# 正确率：0.6144708262382774
# 召回率：0.5976808584285219
# 准确率：0.7266297220694614
# f-measure：0.6059595602613543

# %%
cp.createClassPlotter(precisions, recalls, f_measures)
