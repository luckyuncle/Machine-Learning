# %%
import kNN
from imp import reload
import createPlotter as cp

# %%
dataMat, labels, features = kNN.file2matrix('vehicle.dat')

# %%
cp.createIRPlotter(dataMat, labels, features, 'vehicle')

# %%
precisions = []
recalls = []
f_measures = []

# %%
kValues = []
kNNPrecisions = []
kNNRecalls = [] 
kNNF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNPrecision, kNNRecall, kNNF_measure = kNN.testKNN('vehicle.dat', i)
    kNNPrecisions.append(kNNPrecision)
    kNNRecalls.append(kNNRecall)
    kNNF_measures.append(kNNF_measure)
# Out:
# 正确率：0.5516450094571692
# 召回率：0.6151138716356107
# 准确率：0.7939999999999999
# f-measure：0.581653164221648
# 正确率：0.5766198815636202
# 召回率：0.6198021509607188
# 准确率：0.798
# f-measure：0.5974317308847725
# 正确率：0.5113895486109642
# 召回率：0.5492053472842947
# 准确率：0.7689999999999999
# f-measure：0.5296232816684797
# 正确率：0.5582843156373103
# 召回率：0.6313663627668203
# 准确率：0.8010000000000002
# f-measure：0.5925805686531994
# 正确率：0.5222067675552249
# 召回率：0.5661644229149949
# 准确率：0.7779999999999998
# f-measure：0.5432979038474439
# 正确率：0.5698923421137577
# 召回率：0.6080155740521873
# 准确率：0.798
# f-measure：0.5883370249621891
# 正确率：0.45200338721572847
# 召回率：0.5419043035007498
# 准确率：0.766
# f-measure：0.49288798752034463
# 正确率：0.5015549379033952
# 召回率：0.5976677805625175
# 准确率：0.7869999999999999
# f-measure：0.5454094452946648

# %%
kValues = []
kNNIPPrecisions = []
kNNIPRecalls = [] 
kNNIPF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIPPrecision, kNNIPRecall, kNNIPF_measure = kNN.testIPKNN('vehicle.dat', i)
    kNNIPPrecisions.append(kNNIPPrecision)
    kNNIPRecalls.append(kNNIPRecall)
    kNNIPF_measures.append(kNNIPF_measure)
# Out:
# 正确率：0.7072384947511988
# 召回率：0.6442712547669445
# 准确率：0.817
# f-measure：0.67428804356801
# 正确率：0.699833732846437
# 召回率：0.6373196516502804
# 准确率：0.813
# f-measure：0.6671153750976451
# 正确率：0.7014835644962687
# 召回率：0.6437697677019145
# 准确率：0.8160000000000001
# f-measure：0.6713886530569766
# 正确率：0.722330108756606
# 召回率：0.6502747252747252
# 准确率：0.82
# f-measure：0.6844111304049839
# 正确率：0.7133459077724051
# 召回率：0.6639324776896037
# 准确率：0.825
# f-measure：0.6877527753231945
# 正确率：0.7073319753446794
# 召回率：0.6669452506671333
# 准确率：0.825
# f-measure：0.6865451783264591
# 正确率：0.7066378010642984
# 召回率：0.6629570973688621
# 准确率：0.825
# f-measure：0.6841008914689166
# 正确率：0.6873254244243354
# 召回率：0.6575159752528174
# 准确率：0.819
# f-measure：0.6720903250969441

# %%
kValues = []
kNNIP2Precisions = []
kNNIP2Recalls = [] 
kNNIP2F_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIP2Precision, kNNIP2Recall, kNNIP2F_measure = kNN.testIP2KNN('vehicle.dat', i)
    kNNIP2Precisions.append(kNNIP2Precision)
    kNNIP2Recalls.append(kNNIP2Recall)
    kNNIP2F_measures.append(kNNIP2F_measure)
# Out:
# 正确率：0.6509857962162863
# 召回率：0.6721331616023061
# 准确率：0.827
# f-measure：0.6613904800977656
# 正确率：0.6539942137247037
# 召回率：0.6708433048433049
# 准确率：0.826
# f-measure：0.6623116171373092
# 正确率：0.6154100903129942
# 召回率：0.6709706597750076
# 准确率：0.8210000000000001
# f-measure：0.6419905060010553
# 正确率：0.6398171647200686
# 召回率：0.682310572722472
# 准确率：0.828
# f-measure：0.6603809960787406
# 正确率：0.6477749457640566
# 召回率：0.6901415082502039
# 准确率：0.8330000000000002
# f-measure：0.668287435639139
# 正确率：0.6440062904091943
# 召回率：0.6981645021645022
# 准确率：0.836
# f-measure：0.6699927216746596
# 正确率：0.6180581644610682
# 召回率：0.6966288349331828
# 准确率：0.8320000000000001
# f-measure：0.6549956593894014
# 正确率：0.6270014969906077
# 召回率：0.7086156863731234
# 准确率：0.836
# f-measure：0.6653150343993104

# %%
kValues = []
kNNIP3Precisions = []
kNNIP3Recalls = [] 
kNNIP3F_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIP3Precision, kNNIP3Recall, kNNIP3F_measure = kNN.testIP3KNN('vehicle.dat', i)
    kNNIP3Precisions.append(kNNIP3Precision)
    kNNIP3Recalls.append(kNNIP3Recall)
    kNNIP3F_measures.append(kNNIP3F_measure)
# Out:
# 正确率：0.6753980204107247
# 召回率：0.6542790456669766
# 准确率：0.818
# f-measure：0.6646708189729299
# 正确率：0.6814222369349411
# 召回率：0.6559384319384318
# 准确率：0.8220000000000001
# f-measure：0.6684375336978075
# 正确率：0.6793176699619531
# 召回率：0.659008337711486
# 准确率：0.8210000000000001
# f-measure：0.6690089049945485
# 正确率：0.6823878454005495
# 召回率：0.6602685418207997
# 准确率：0.82
# f-measure：0.6711459937583857
# 正确率：0.6825833146822257
# 召回率：0.6720683760683761
# 准确率：0.825
# f-measure：0.6772850363855037
# 正确率：0.672868324053442
# 召回率：0.6683789008770076
# 准确率：0.8220000000000001
# f-measure：0.6706160989658183
# 正确率：0.6669748490737601
# 召回率：0.6674658433354085
# 准确率：0.8230000000000001
# f-measure：0.6672202558763419
# 正确率：0.6719007749996859
# 召回率：0.6612069796507183
# 准确率：0.8219999999999998
# f-measure：0.6665109860965799

# %%
cp.createKNNPlotter(kValues, kNNPrecisions, kNNIPPrecisions, kNNIP2Precisions, kNNIP3Precisions, 'precision')

# %%
cp.createKNNPlotter(kValues, kNNRecalls, kNNIPRecalls, kNNIP2Recalls, kNNIP3Recalls, 'recall')

# %%
cp.createKNNPlotter(kValues, kNNF_measures, kNNIPF_measures, kNNIP2F_measures, kNNIP3F_measures, 'F-measure')

# %%
precisions.append(kNNIPPrecisions[3])
recalls.append(kNNIPRecalls[3])
f_measures.append(kNNIPF_measures[3])
precisions.append(kNNIP2Precisions[3])
recalls.append(kNNIP2Recalls[3])
f_measures.append(kNNIP2F_measures[3])
precisions.append(kNNIP3Precisions[3])
recalls.append(kNNIP3Recalls[3])
f_measures.append(kNNIP3F_measures[3])
precisions.append(kNNPrecisions[3])
recalls.append(kNNRecalls[3])
f_measures.append(kNNF_measures[3])

# %%
SVMs = kNN.testSVM('vehicle.dat')
precisions.append(SVMs[0])
recalls.append(SVMs[1])
f_measures.append(SVMs[2])
# Out:
# 正确率：0.5454539812543443
# 召回率：0.6397903825864846
# 准确率：0.8099999999999999
# f-measure：0.5888679533040218

# %%
RFs = kNN.testRandomForest('vehicle.dat')
precisions.append(RFs[0])
recalls.append(RFs[1])
f_measures.append(RFs[2])
# Out:
# 正确率：0.5673355819081772
# 召回率：0.7025339622014813
# 准确率：0.829
# f-measure：0.627737732753147

# %%
reload(kNN)
bayes = kNN.testBayes('vehicle.dat')
precisions.append(bayes[0])
recalls.append(bayes[1])
f_measures.append(bayes[2])
# Out:
# 正确率：0.6542875324245561
# 召回率：0.4169770063949086
# 准确率：0.6869999999999999
# f-measure：0.5093473119021644

# %%
trees = kNN.testDecisionTree('vehicle.dat')
precisions.append(trees[0])
recalls.append(trees[1])
f_measures.append(trees[2])
# Out:
# 正确率：0.6694139352950605
# 召回率：0.6644177114177768
# 准确率：0.8190000000000002
# f-measure：0.6669064660087004

# %%
cp.createClassPlotter(precisions, recalls, f_measures)
