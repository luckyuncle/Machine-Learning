# %%
import algorithmTest as at
import createPlotter as cp
import dataTreat as dt
from imp import reload
fileName = 'vehicle1-5-fold'
file = 'vehicle1-5-fold'

# %%
dataMat, labels, features, length = dt.createIR(fileName)

# %%
print(length)
cp.createIRPlotter(dataMat, labels, features, file)
# Out:
# 4230

# %%
precisions = []
recalls = []
f_measures = []

# %%
kValues = []
kNNPrecisions = []
kNNRecalls = [] 
kNNF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNs = at.testKNNByDir(fileName, 'KNN', i)
    kNNPrecisions.append(kNNs[0])
    kNNRecalls.append(kNNs[1])
    kNNF_measures.append(kNNs[2])
# Out:
# 正确率：0.4710683224848188
# 召回率：0.4053987338047116
# 准确率：0.7274053699163144
# f-measure：0.435773370146545
# 正确率：0.48974789110194966
# 召回率：0.4179886412975306
# 准确率：0.7330078801205746
# f-measure：0.4510318760420799
# 正确率：0.46420457028717343
# 召回率：0.38105512434607464
# 准确率：0.7262480662162516
# f-measure：0.4185400803466566
# 正确率：0.4830171693196436
# 召回率：0.3869197231175806
# 准确率：0.7315534382405126
# f-measure：0.42966075134623677
# 正确率：0.4922693210765229
# 召回率：0.3718265016631964
# 准确率：0.7368485070341142
# f-measure：0.4236538928093737
# 正确率：0.47867810940320143
# 召回率：0.3604605792033654
# 准确率：0.7306480392756685
# f-measure：0.41124212459794723
# 正确率：0.500529345196824
# 召回率：0.362584281799879
# 准确率：0.7394916250261565
# f-measure：0.42053344419887695
# 正确率：0.5121002008743945
# 召回率：0.35909461741284704
# 准确率：0.7439437928947811
# f-measure：0.42216143128941713

# %%
kValues = []
kNNIPDCPrecisions = []
kNNIPDCRecalls = [] 
kNNIPDCF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIPDCs = at.testKNNByDir(fileName, 'IPDC_KNN', i)
    kNNIPDCPrecisions.append(kNNIPDCs[0])
    kNNIPDCRecalls.append(kNNIPDCs[1])
    kNNIPDCF_measures.append(kNNIPDCs[2])
# Out:
# 正确率：0.486159044078809
# 召回率：0.6209927332341357
# 准确率：0.7303769368042813
# f-measure：0.5453655763470986
# 正确率：0.4733722917472466
# 召回率：0.6037555679259932
# 准确率：0.7218044535251804
# f-measure：0.5306726667175597
# 正确率：0.4811664596450421
# 召回率：0.623113696729218
# 准确率：0.7280013943294186
# f-measure：0.5430169322175477
# 正确率：0.47350252551187133
# 召回率：0.617418816896407
# 准确率：0.7212083982640805
# f-measure：0.5359678241395855
# 正确率：0.4709999956652431
# 召回率：0.6072908348401903
# 准确率：0.7206262657318353
# f-measure：0.5305321579025154
# 正确率：0.47374667630000306
# 召回率：0.6084402601275467
# 准确率：0.7218062015782862
# f-measure：0.5327112003663187
# 正确率：0.4790528095508563
# 召回率：0.6118296453088393
# 准确率：0.7265347160776155
# f-measure：0.5373607564151361
# 正确率：0.4786398168492071
# 召回率：0.6106146852639013
# 准确率：0.7250541150969578
# f-measure：0.5366321654914789

# %%
kValues = []
kNNIPDSPrecisions = []
kNNIPDSRecalls = [] 
kNNIPDSF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIPDSs = at.testKNNByDir(fileName, 'IPDS_KNN', i)
    kNNIPDSPrecisions.append(kNNIPDSs[0])
    kNNIPDSRecalls.append(kNNIPDSs[1])
    kNNIPDSF_measures.append(kNNIPDSs[2])
# Out:
# 正确率：0.5084568856631133
# 召回率：0.45020155572533305
# 准确率：0.7430365841808391
# f-measure：0.477559203699826
# 正确率：0.4977502408079909
# 召回率：0.436525018601308
# 准确率：0.7377346157188021
# f-measure：0.4651315143780873
# 正确率：0.5044786926628358
# 召回率：0.4202473183845819
# 准确率：0.7430644296385489
# f-measure：0.4585267749386261
# 正确率：0.5110227272727272
# 召回率：0.41817860149347047
# 准确率：0.744553709188744
# f-measure：0.4599622553403781
# 正确率：0.5314709417096555
# 召回率：0.4215945629819853
# 准确率：0.7543078763674018
# f-measure：0.4701990750996732
# 正确率：0.5117355859251513
# 召回率：0.4019461947770814
# 准确率：0.7454260493845568
# f-measure：0.4502446603160818
# 正确率：0.5286090629800306
# 召回率：0.4111763415240895
# 准确率：0.7519392644089704
# f-measure：0.4625556846720599
# 正确率：0.5225368503053666
# 召回率：0.3984713426077903
# 准确率：0.7495671871923234
# f-measure：0.45214790032352803

# %%
kValues = []
kNNIPDCSPrecisions = []
kNNIPDCSRecalls = [] 
kNNIPDCSF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIPDCSs = at.testKNNByDir(fileName, 'IPDCS_KNN', i)
    kNNIPDCSPrecisions.append(kNNIPDCSs[0])
    kNNIPDCSRecalls.append(kNNIPDCSs[1])
    kNNIPDCSF_measures.append(kNNIPDCSs[2])
# Out:
# 正确率：0.4871897423456459
# 召回率：0.5638594037495911
# 准确率：0.7318540416787273
# f-measure：0.5227282066732992
# 正确率：0.4777891723553423
# 召回率：0.5464373982581844
# 准确率：0.7268301062045088
# f-measure：0.5098127304027908
# 正确率：0.49684157394412953
# 召回率：0.5535133611260825
# 准确率：0.7371820766973725
# f-measure：0.5236486074540222
# 正确率：0.48147796662272774
# 召回率：0.5511088023061268
# 准确率：0.7262444775660519
# f-measure：0.5139456624986509
# 正确率：0.4962027179489735
# 召回率：0.5558122117007953
# 准确率：0.7368727329936283
# f-measure：0.5243186619166731
# 正确率：0.493448821010392
# 召回率：0.5604044838107166
# 准确率：0.7344884811012323
# f-measure：0.5247996672027831
# 正确率：0.5049703592051149
# 召回率：0.561659617343316
# 准确率：0.7418757843745646
# f-measure：0.5318085277120163
# 正确率：0.5001175794253218
# 召回率：0.5707505264342252
# 准确率：0.7383324498810039
# f-measure：0.5331046282434542

# %%
kValues = []
kNNIPNCPrecisions = []
kNNIPNCRecalls = [] 
kNNIPNCF_measures = []
for i in range(3, 11):
    kValues.append(i)
for i in kValues:
    kNNIPNCs = at.testKNNByDir(fileName, 'IPNC_KNN', i)
    kNNIPNCPrecisions.append(kNNIPNCs[0])
    kNNIPNCRecalls.append(kNNIPNCs[1])
    kNNIPNCF_measures.append(kNNIPNCs[2])
# Out:
# 正确率：0.39555555555555555
# 召回率：0.10144176466679955
# 准确率：0.7684672607647938
# f-measure：0.16147311845206586
# 正确率：0.4
# 召回率：0.10144176466679955
# 准确率：0.7687626817396831
# f-measure：0.16184015263938947
# 正确率：0.4
# 召回率：0.10144176466679955
# 准确率：0.7687626817396831
# f-measure：0.16184015263938947
# 正确率：0.4
# 召回率：0.10144176466679955
# 准确率：0.7687626817396831
# f-measure：0.16184015263938947
# 正确率：0.4
# 召回率：0.10144176466679955
# 准确率：0.7687626817396831
# f-measure：0.16184015263938947
# 正确率：0.4
# 召回率：0.10144176466679955
# 准确率：0.7687626817396831
# f-measure：0.16184015263938947
# 正确率：0.4
# 召回率：0.10144176466679955
# 准确率：0.7687626817396831
# f-measure：0.16184015263938947
# 正确率：0.4
# 召回率：0.10144176466679955
# 准确率：0.7687626817396831
# f-measure：0.16184015263938947

# %%
cp.createKNNPlotter(kValues, kNNPrecisions, kNNIPDCPrecisions, kNNIPDSPrecisions, kNNIPDCSPrecisions, 'precision')

# %%
cp.createKNNPlotter(kValues, kNNRecalls, kNNIPDCRecalls, kNNIPDSRecalls, kNNIPDCSRecalls, 'recall')

# %%
cp.createKNNPlotter(kValues, kNNF_measures, kNNIPDCF_measures, kNNIPDSF_measures, kNNIPDCSF_measures, 'F-measure')

# %%
precisions.append(kNNIPDCPrecisions[3])
recalls.append(kNNIPDCRecalls[3])
f_measures.append(kNNIPDCF_measures[3])
precisions.append(kNNIPDSPrecisions[3])
recalls.append(kNNIPDSRecalls[3])
f_measures.append(kNNIPDSF_measures[3])
precisions.append(kNNIPDCSPrecisions[3])
recalls.append(kNNIPDCSRecalls[3])
f_measures.append(kNNIPDCSF_measures[3])
precisions.append(kNNPrecisions[3])
recalls.append(kNNRecalls[3])
f_measures.append(kNNF_measures[3])

# %%
SVMs = at.testOthersByDir(fileName, 'SVM', 0)
precisions.append(SVMs[0])
recalls.append(SVMs[1])
f_measures.append(SVMs[2])
# Out:
# 正确率：0.6510444622860755
# 召回率：0.5313444858306282
# 准确率：0.8036278785678921
# f-measure：0.5851355184218601

# %%
RFs = at.testOthersByDir(fileName, 'RF')
precisions.append(RFs[0])
recalls.append(RFs[1])
f_measures.append(RFs[2])
# Out:
# 正确率：0.6396756866322083
# 召回率：0.42211195817237607
# 准确率：0.7915450578682698
# f-measure：0.5086040659839759

# %%
bayes = at.testOthersByDir(fileName, 'Bayes')
precisions.append(bayes[0])
recalls.append(bayes[1])
f_measures.append(bayes[2])
# Out:
# 正确率：0.4295654758862849
# 召回率：0.629948358807679
# 准确率：0.6890092292062657
# f-measure：0.5108079907482617

# %%
trees = at.testOthersByDir(fileName, 'Tree')
precisions.append(trees[0])
recalls.append(trees[1])
f_measures.append(trees[2])
# Out:
# 正确率：0.5537341153470186
# 召回率：0.5599949389833551
# 准确率：0.7696628982412015
# f-measure：0.5568469295670757

# %%
cp.createClassPlotter(precisions, recalls, f_measures)
