# %%
import regression
from numpy import mat
from imp import reload

# %%
xArr, yArr = regression.loadDataSet('Ch08/ex0.txt')

# %%
xArr[0:2]
# Out:
# [[1.0, 0.067732], [1.0, 0.42781]]

# %%
ws = regression.standRegres(xArr, yArr)

# %%
ws
# Out:
# matrix([[3.00774324],
#         [1.69532264]])

# %%
reload(regression)
# Out:
# <module 'regression' from 'F:\\pythonCode\\regression\\regression.py'>

# %%
regression.plot(xArr, yArr)
